# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## EDA for Car Price Prediction Model

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_json('scout_car.json', lines=True)

# %%
df.sample(20).T
# Out:
#                                                                            9524   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                      1.2 ENJOY +Airco+Cruise Control+Bluetooth
# body_type                                                                 Sedans
# price                                                                       9745
# vat                                                               VAT deductible
# km                                                                     27,941 km
# registration                                                             01/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         51 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                             [\n12 months\n, \nEuro 6\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                        [\n425163\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,229 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                        [[], [], []]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n         [Bluetooth, CD player, MP3, On-board computer]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\nAlle DECAIGNY TWEEDEHANDS zijn gecertificee...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            7161   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                       K Sports Tourer Frontkamera Keyless Open
# body_type                                                          Station wagon
# price                                                                      18380
# vat                                                               VAT deductible
# km                                                                     21,650 km
# registration                                                             06/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                                                    [, Used, , Super E10 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n06/2021\n, \n128 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                         [\n54786\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nOnyx Schwarz\n]
# Upholstery                                                           [\nCloth\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n1844/AEV\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,340 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                      [\n, Super E10 95, \n]
# Consumption                    [[5.6 l/100 km (comb)], [7.3 l/100 km (city)],...
# CO2 Emission                                           [\n128 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                               [Alloy wheels, Roof rack, Touch screen]
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Central door lo...
# description                    [\n,  Ihre Ansprechpartner:,  Axel Thieme Tel ...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n6\n]
# Country version                                                    [\nBelgium\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1262   \
# url                            https://www.autoscout24.com//offers/audi-a1-ad...
# make_model                                                               Audi A1
# short_description                       ADRENALIN 1.0 TFSI 70KW (95CV) SPORTBACK
# body_type                                                                Compact
# price                                                                      15700
# vat                                                                         None
# km                                                                      4,490 km
# registration                                                             06/2018
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         70 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n24 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                       [\n2771154\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                                   NaN
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                                 NaN
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                                 NaN
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                                 NaN
# Emission Class                                                               NaN
# \nComfort & Convenience\n                                                    NaN
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n                                                        NaN
# description                    [\nSOMOS CONCESIONARIO OFICIAL AUDI (MOTOR GOM...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            10335  \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                                                  1.2 Selection
# body_type                                                                Compact
# price                                                                      10250
# vat                                                               VAT deductible
# km                                                                         22 km
# registration                                                             02/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         51 kW
# Type                                              [, Pre-registered, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n02/2022\n, \n132 g CO2/km (comb)\n]
# Inspection new                                             [\nYes\n, \nEuro 6\n]
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                       [\n1177571\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                        [\n, Blue, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                   [\nblau\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n3\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n1844/ACP\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,229 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.8 l/100 km (comb)], [7.3 l/100 km (city)],...
# CO2 Emission                                           [\n132 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Electrical side mirrors, Hill Holder, Power w...
# \nEntertainment & Media\n                                           [MP3, Radio]
# \nExtras\n                                                 [Catalytic Converter]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nFahrzeug-Nr.: 1177571, , Fahrzeugstandort: ...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n5\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            10337  \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                                             1,4 Ecotec Edition
# body_type                                                                 Sedans
# price                                                                      10990
# vat                                                                         None
# km                                                                         30 km
# registration                                                             06/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         55 kW
# Type                                              [, Pre-registered, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n06/2022\n, \n128 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                    [\n2021067381\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                           [\nSchnee Weiss\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,119 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                                      [[5.6 l/100 km (comb)], [], []]
# CO2 Emission                                           [\n128 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n                                                    NaN
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n                                                        NaN
# description                                                                   []
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            633    \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description              SPB 1.6 TDI 116 CV S LINE NAVI BOSE FULL LED EUR6
# body_type                                                                 Sedans
# price                                                                      12550
# vat                                                                         None
# km                                                                     95,000 km
# registration                                                             01/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                 [\n12 months\n, \n99 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                              [\nPart leather, Grey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n4\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,250 kg\n]
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2 Emission                                            [\n99 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Sport pack...
# \nSafety & Security\n          [ABS, Adaptive headlights, Alarm system, Centr...
# description                    [\n, S-LINE,  SPORTSWORK / SPORTSITZE / SPORTP...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            999    \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                       Sportback 1.4 TDI ultra sport XENON NAVI
# body_type                                                                Compact
# price                                                                      20860
# vat                                                               VAT deductible
# km                                                                     30,589 km
# registration                                                             05/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n109 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                        [\nF-9585\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                          [\nmythosschwarz\n]
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,422 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2 Emission                                           [\n109 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                         [Alloy wheels, Sport seats, Sport suspension]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nFahrzeug-Nr.: F-9585., Media:, MMI Navigati...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            14656  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                                         scambio con anni 80/90
# body_type                                                                 Sedans
# price                                                                      10000
# vat                                                                         None
# km                                                                     13,000 km
# registration                                                             08/2018
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         55 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,461 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,162 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[4 l/100 km (comb)], [4.5 l/100 km (city)], [...
# CO2 Emission                                           [\n104 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Power windows, Seat ventila...
# \nEntertainment & Media\n                                    [On-board computer]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Alarm system, Central door lock, Driver-...
# description                    [\nValuto scambio con auto anni 80/90 , Auto p...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            7268   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                       K Lim. 5türig Dynamic NAVI RF 900 SH LRH
# body_type                                                                 Sedans
# price                                                                      15450
# vat                                                               VAT deductible
# km                                                                     25,520 km
# registration                                                             04/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                                              [, Employee's car, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n128 g CO2/km (comb)\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nOnyx Schwarz\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.4 l/100 km (comb)], [7.1 l/100 km (city)],...
# CO2 Emission                                           [\n128 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                           [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n          [ABS, Alarm system, Central door lock, Daytime...
# description                    [\n, Sonderausstattung:, Allwetter-/ Ganzjahre...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            2403   \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.0 TFSI 116 PDC 15ZLM LaneAssist
# body_type                                                                Compact
# price                                                                      19388
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                               [, New, , Regular/Benzine 91]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                           \nYes\n
# Warranty                                       [\n, \n, \n111 g CO2/km (comb)\n]
# Full Service                                          [\n, \n, \nEuro 6d-TEMP\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                    [\nGW-AHM1067\n]
# First Registration                                                           NaN
# Body Color                                                       [\n, Green, \n]
# Paint Type                                                                   NaN
# Body Color Original                                            [\nTioman Grün\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BNO\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,180 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                [\n, Regular/Benzine 91, \n]
# Consumption                    [[4.9 l/100 km (comb)], [6 l/100 km (city)], [...
# CO2 Emission                                           [\n111 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Electrical side mirrors, Li...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, Radio, ...
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Aktionspreis,  auf limitierte Stückzahl -...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                             [\nEuropean Union\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            9705   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                      E 1.4 Turbo 90 Aut 120 Jahre R4.0 PDC SHZ
# body_type                                                                Compact
# price                                                                      14213
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                               [, New, , Regular/Benzine 91]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n143 g CO2/km (comb)\n]
# Warranty                                              [\n, \n, \nEuro 6d-TEMP\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# ...
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,403 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.5 l/100 km (city)],...
# CO2 Emission                                           [\n101 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                           [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Central door lock wit...
# description                    [\n, AUTOVETTURA VISIONABILE PRESSO LA NOSTRA ...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            11355  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                  1.6 CDTI 136 S&S aut.Sports Tourer Innovation
# body_type                                                          Station wagon
# price                                                                      21650
# vat                                                               VAT deductible
# km                                                                     13,000 km
# registration                                                             05/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n06/2022\n, \n137 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                             [\n16 months\n, \nEuro 6\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                      [\n11646062\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                   [\nNero\n]
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,585 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[5.2 l/100 km (comb)], [6.8 l/100 km (city)],...
# CO2 Emission                                           [\n137 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                           [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Alarm system, C...
# description                    [\n, Led Diurni, Clima Bi-Zona, Navigatore, Sc...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            15054  \
# url                            https://www.autoscout24.com//offers/renault-es...
# make_model                                                        Renault Espace
# short_description                          1.6 dCi Energy Initiale Paris EDC 7PL
# body_type                                                                    Van
# price                                                                      24998
# vat                                                               VAT deductible
# km                                                                     42,710 km
# registration                                                             09/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        118 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                         [\n12 months\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                           [\n, Espace, \n]
# Offer Number                                                 [\nREN5635209101\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                      [\n, Violet, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                             [\nFull leather, Black\n]
# Body                                                               [\n, Van, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n7\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,734 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                                 NaN
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Cruise control, Electrically adjustable seats...
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                         [Sport seats]
# \nSafety & Security\n          [ABS, Central door lock, Electronic stability ...
# description                    [\n*Véhicule en très bon état, entièrement rév...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            12372
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                                 1.6 CDTI Business Edition ST(E
# body_type                                                          Station wagon
# price                                                                      19900
# vat                                                               VAT deductible
# km                                                                     26,700 km
# registration                                                             03/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n03/2021\n, \n132 g CO2/km (comb)\n]
# Inspection new                                             [\nYes\n, \nEuro 6\n]
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                        [\nAL28-HL1904-0316-0956Y\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                            [\nOnyxSchwarz\n]
# Upholstery                                                                   NaN
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BKX\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[5 l/100 km (comb)], [6 l/100 km (city)], [4....
# CO2 Emission                                           [\n132 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n          [Bluetooth, Hands-free equipment, Radio, USB]
# \nExtras\n                                         [Alloy wheels, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Sicherheit:,  , Anti-Blockier-System (ABS...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %%
df.short_description.describe()
# Out:
# count                                 15873
# unique                                10001
# top       SPB 1.6 TDI 116 CV S tronic Sport
# freq                                     64
# Name: short_description, dtype: object

# %%
df.short_description.unique()
# Out:
# array(['Sportback 1.4 TDI S-tronic Xenon Navi Klima', '1.8 TFSI sport',
#        'Sportback 1.6 TDI S tronic Einparkhilfe plus+music', ...,
#        'ELYSEE ENERGY dCi 160 EDC',
#        'INITIALE Paris TCe 225 EDC GPF ACC EU6',
#        'TCe 225 EDC GPF LIM Deluxe Pano,RFK'], dtype=object)

# %%
df.body_type.describe()
# Out:
# count      15859
# unique         9
# top       Sedans
# freq        7903
# Name: body_type, dtype: object

# %%
df.body_type.unique()
# Out:
# array(['Sedans', 'Station wagon', 'Compact', 'Other', 'Coupe', 'Van',
#        'Off-Road', 'Convertible', None, 'Transporter'], dtype=object)

# %%
df.body_type.isna().sum()
# Out:
# 60

# %%
df.price.describe()
# Out:
# count    15919.000000
# mean     18019.896727
# std       7386.169409
# min         13.000000
# 25%      12850.000000
# 50%      16900.000000
# 75%      21900.000000
# max      74600.000000
# Name: price, dtype: float64

# %%
df[df.price<5000].T
# Out:
#                                                                             6066  \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                 1.6 D (CDTI) Start/Stop Sports Tourer Business
# body_type                                                          Station wagon
# price                                                                        255
# vat                                                                         None
# km                                                                      5,563 km
# registration                                                             06/2018
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Gold, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,403 kg\n]
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.5 l/100 km (city)],...
# CO2 Emission                                           [\n101 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                                           [Roof rack]
# \nSafety & Security\n          [ABS, Central door lock with remote control, D...
# description                                                                   []
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                             8594  \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                            1.4 (ecoFLEX) Start/Stop Innovation
# body_type                                                                 Sedans
# price                                                                         13
# vat                                                                         None
# km                                                                        123 km
# registration                                                             06/2018
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Gold, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n3\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n1844/ADJ\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,141 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.6 l/100 km (comb)], [6.8 l/100 km (city)],...
# CO2 Emission                                           [\n128 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Adaptive headlights, Central door lock w...
# description                                                                   []
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                             8825  \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                                                  Color Edition
# body_type                                                                Compact
# price                                                                       4990
# vat                                                               VAT deductible
# km                                                                     79,000 km
# registration                                                             06/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                           \n
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                        [\n098551\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                         [\n, Red, \n]
# Paint Type                                                                   NaN
# Body Color Original                                               [\nMagmarot\n]
# Upholstery                                                           [\nBlack\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n3\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,141 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.2 l/100 km (comb)], [6.6 l/100 km (city)],...
# CO2 Emission                                           [\n123 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                          [Alloy wheels, Touch screen]
# \nSafety & Security\n          [ABS, Central door lock, Central door lock wit...
# description                    [\n, Pakete:, Funktions-Paket, Komfort-Paket (...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                             8827  \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                                                  LICHTE VRACHT
# body_type                                                                 Sedans
# price                                                                       4950
# vat                                                                         None
# km                                                                    179,521 km
# registration                                                             05/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         70 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2016, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,248 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,163 kg\n]
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.2 l/100 km (comb)], [3.7 l/100 km (city)],...
# CO2 Emission                                            [\n94 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, CD player, MP3, On-board computer,...
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock with remote control, D...
# description                    [\nGoede staat, Proper binnen en buiten , Onde...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                             8828  \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                    1.0 Turbo 120 Jaar Edition / 120 EURO p/mnd
# body_type                                                                Compact
# price                                                                        120
# vat                                                                         None
# km                                                                         12 km
# registration                                                             01/2019
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                         [, New, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                      \n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                         [\n49361\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                              [\nSovereign Silver (grijs m\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,099 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[4.6 l/100 km (comb)], [5.6 l/100 km (city)],...
# CO2 Emission                                           [\n107 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n              [Digital radio, On-board computer, Radio]
# \nExtras\n                                      [Alloy wheels, Sport suspension]
# \nSafety & Security\n          [Central door lock, Daytime running lights, Dr...
# description                    [\nOpel Bestaat 120 jaar en trakteert! €120 PE...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                [\nNetherlands\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                             8829
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                  Corsa1.0 Turbo 90 Pk OPC Line | Private Lease
# body_type                                                                  Other
# price                                                                        331
# vat                                                                         None
# km                                                                         10 km
# registration                                                             01/2019
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                         [, New, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                      \n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                         [\n62535\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                               [\nAbalone White (wit mica)\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                             [\n, Other, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,163 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                        [[], [], []]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n       [Hands-free equipment, On-board computer, Radio]
# \nExtras\n                                         [Alloy wheels, Sport package]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\nOpel heeft – Bepaal ’t Zelf Lease., Dat is ...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                [\nNetherlands\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.sample(3).T
# Out:
#                                                                            14019  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                 dCi90 SS I.Paris Leder R-Link/Navi Bose P.Dach
# body_type                                                                 Sedans
# price                                                                      18087
# vat                                                               VAT deductible
# km                                                                          - km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                      [, New, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n109 g CO2/km (comb)\n]
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                        [\n, \n, \nEuro 6c\n]
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                         [\n68716\n]
# First Registration                                                           NaN
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                            [\nblack pearl\n]
# Upholstery                                             [\nFull leather, Other\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,461 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,308 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                           [\n109 g CO2/km (comb)\n]
# Emission Class                                                     [\nEuro 6c\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Digital radio, Radio, Sound system...
# \nExtras\n                      [Alloy wheels, Catalytic Converter, Sport seats]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n,  , Neues Fahrzeug inkl.19% MWST, Fahrzeug...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n6\n]
# Country version                                                   [\nBulgaria\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                        \nin 42 days from ordering\n
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            5370   \
# url                            https://www.autoscout24.com//offers/audi-a3-1-...
# make_model                                                               Audi A3
# short_description                  1.5 TFSI Sportback Sport PDC SH MMI Xenon Alu
# body_type                                                          Station wagon
# price                                                                      24950
# vat                                                               VAT deductible
# km                                                                          - km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                                                         [, New, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                                 NaN
# First Registration                                                           NaN
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                [\nSchwarz\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BHX\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,498 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5 l/100 km (comb)], [6.3 l/100 km (city)], [...
# CO2 Emission                                           [\n114 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                         [Alloy wheels, Sport seats, Sport suspension]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, - seit über 50 Jahren Opel-Partner, - Ver...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                    [\nDenmark\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                       \nin 150 days from ordering\n
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            4830
# url                            https://www.autoscout24.com//offers/audi-a3-li...
# make_model                                                               Audi A3
# short_description                Limousine 1.6 TDI Sitzh,.Navi,PDC,Xenon,connect
# body_type                                                                 Sedans
# price                                                                      21380
# vat                                                               VAT deductible
# km                                                                     16,856 km
# registration                                                             07/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                           [, Employee's car, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n109 g CO2/km (comb)\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                       [\n1079017\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                          [\nMythosschwarz\n]
# Upholstery                                                     [\nOther, Grey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BLG\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,495 kg\n]
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.7 l/100 km (city)],...
# CO2 Emission                                           [\n109 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                                     [Alloy wheels, Cab or rented Car]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Ausstattungspakete:,  Businesspaket, Nich...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.vat.describe()
# Out:
# count              11406
# unique                 2
# top       VAT deductible
# freq               10980
# Name: vat, dtype: object

# %%
df.vat.unique()
# Out:
# array(['VAT deductible', 'Price negotiable', None], dtype=object)

# %%
df.registration.describe()
# Out:
# count     15919
# unique       48
# top         -/-
# freq       1597
# Name: registration, dtype: object

# %%
df.registration.unique()
# Out:
# array(['01/2016', '03/2017', '02/2016', '08/2016', '05/2016', '03/2016',
#        '06/2017', '05/2018', '09/2016', '06/2016', '10/2016', '04/2016',
#        '06/2018', '11/2017', '07/2016', '12/2016', '09/2018', '04/2018',
#        '07/2017', '02/2017', '11/2016', '01/2018', '05/2017', '04/2017',
#        '07/2018', '01/2017', '02/2018', '03/2018', '-/-', '08/2017',
#        '10/2017', '08/2018', '09/2017', '12/2017', '04/2019', '12/2018',
#        '03/2019', '06/2019', '05/2019', '02/2019', '01/2019', '10/2018',
#        '11/2018', '09/2019', '07/2019', '08/2019', '11/2019', '12/2019'],
#       dtype=object)

# %%
df.prev_owner.describe()
# Out:
# count                 9091
# unique                   4
# top       1 previous owner
# freq                  8294
# Name: prev_owner, dtype: object

# %%
df.prev_owner.unique()
# Out:
# array(['2 previous owners', None, '1 previous owner', '3 previous owners',
#        '4 previous owners'], dtype=object)

# %%
df.prev_owner.value_counts()
# Out:
# 1 previous owner     8294
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
df.prev_owner.isnull().sum()
# Out:
# 6828

# %%
df['Previous Owners'].describe()
# Out:
# count      9279
# unique      102
# top       \n1\n
# freq       8101
# Name: Previous Owners, dtype: object

# %%
#df['Previous Owners'].value_counts(dropna=False)

# %%
df.Type.describe()
# Out:
# count                                       15917
# unique                                        169
# top       [, Used, , Diesel (Particulate Filter)]
# freq                                         3475
# Name: Type, dtype: object

# %%
df['Next Inspection'].describe()
# Out:
# count            3535
# unique           1399
# top       \n04/2022\n
# freq               62
# Name: Next Inspection, dtype: object

# %%
df['Inspection new'].describe()
# Out:
# count                      3932
# unique                      202
# top       [\nYes\n, \nEuro 6\n]
# freq                        523
# Name: Inspection new, dtype: object

# %%
df.Warranty.describe()
# Out:
# count                    10499
# unique                     515
# top       [\n, \n, \nEuro 6\n]
# freq                      1868
# Name: Warranty, dtype: object

# %%
df.Warranty.str.contains("CO", case = False).value_counts()
# Out:
# False    3036
# Name: Warranty, dtype: int64

# %%
df.Warranty.isna().sum()
# Out:
# 5420

# %%
df.Warranty.dtype.type
# Out:
# numpy.object_

# %%
df['Full Service'].describe()
# Out:
# count                        8215
# unique                        122
# top       [\n, \n, \n4 (Green)\n]
# freq                         2235
# Name: Full Service, dtype: object

# %%
df['Non-smoking Vehicle'].describe()
# Out:
# count         7177
# unique          94
# top       [\n, \n]
# freq          3647
# Name: Non-smoking Vehicle, dtype: object

# %%
df['Non-smoking Vehicle'].isnull().sum()
# Out:
# 8742

# %%
df['Make'].describe()
# Out:
# count        15919
# unique           3
# top       \nOpel\n
# freq          7343
# Name: Make, dtype: object

# %%
df['Make'].unique()
# Out:
# array(['\nAudi\n', '\nOpel\n', '\nRenault\n'], dtype=object)

# %%
df['Model'].describe()
# Out:
# count            15919
# unique               9
# top       [\n, A3, \n]
# freq              3097
# Name: Model, dtype: object

# %%
df['First Registration'].describe()
# Out:
# count              14322
# unique                 4
# top       [\n, 2018, \n]
# freq                4522
# Name: First Registration, dtype: object

# %%
df['First Registration'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, 2018, \n]    4522
# [\n, 2016, \n]    3674
# [\n, 2017, \n]    3273
# [\n, 2019, \n]    2853
# Name: First Registration, dtype: int64

# %%
df.registration.isin(['2018']).value_counts()
# Out:
# False    15919
# Name: registration, dtype: int64

# %%
df.registration.value_counts()
# Out:
# -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 04/2018     541
# 01/2019     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# 06/2018     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2016     141
# 09/2018     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 12/2019       1
# 11/2019       1
# 08/2019       1
# Name: registration, dtype: int64

# %%
df.registration.isnull().sum()
# Out:
# 0

# %%
df['Body Color'].describe()
# Out:
# count               15322
# unique                 14
# top       [\n, Black, \n]
# freq                 3745
# Name: Body Color, dtype: object

# %%
df['Body Color'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Black, \n]     3745
# [\n, Grey, \n]      3505
# [\n, White, \n]     3406
# [\n, Silver, \n]    1647
# [\n, Blue, \n]      1431
# [\n, Red, \n]        957
# [\n, Brown, \n]      289
# [\n, Green, \n]      154
# [\n, Beige, \n]      108
# [\n, Yellow, \n]      51
# [\n, Violet, \n]      18
# [\n, Bronze, \n]       6
# [\n, Orange, \n]       3
# [\n, Gold, \n]         2
# Name: Body Color, dtype: int64

# %%
df['Body Color Original'].describe()
# Out:
# count                  12160
# unique                  1927
# top       [\nOnyx Schwarz\n]
# freq                     338
# Name: Body Color Original, dtype: object

# %%
df['Paint Type'].describe()
# Out:
# count              10147
# unique                 3
# top       [\nMetallic\n]
# freq                9794
# Name: Paint Type, dtype: object

# %%
df['Paint Type'].isnull().sum()
# Out:
# 5772

# %%
df['Upholstery'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nCloth, Black\n]           5821
# [\nPart leather, Black\n]    1121
# [\nCloth\n]                  1005
# [\nCloth, Grey\n]             891
# [\nCloth, Other\n]            639
# [\nFull leather, Black\n]     575
# [\nBlack\n]                   491
# [\nGrey\n]                    273
# [\nOther, Other\n]            182
# [\nPart leather\n]            140
# [\nFull leather\n]            139
# [\nFull leather, Brown\n]     116
# [\nPart leather, Grey\n]      116
# [\nOther, Black\n]            110
# [\nFull leather, Other\n]      72
# [\nFull leather, Grey\n]       67
# [\nPart leather, Other\n]      65
# [\nOther\n]                    56
# [\nPart leather, Brown\n]      50
# [\nalcantara, Black\n]         47
# [\nVelour, Black\n]            36
# [\nFull leather, Beige\n]      36
# [\nCloth, Brown\n]             28
# [\nVelour\n]                   16
# [\nOther, Grey\n]              15
# [\nCloth, Beige\n]             13
# [\nBrown\n]                    12
# [\nCloth, Blue\n]              12
# [\nCloth, White\n]              8
# [\nVelour, Grey\n]              8
# [\nalcantara, Grey\n]           6
# [\nCloth, Red\n]                5
# [\nOther, Yellow\n]             4
# [\nPart leather, Red\n]         3
# [\nBeige\n]                     3
# [\nBlue\n]                      2
# [\nFull leather, Blue\n]        2
# [\nalcantara\n]                 2
# [\nalcantara, Other\n]          2
# [\nPart leather, Beige\n]       2
# [\nWhite\n]                     2
# [\nPart leather, White\n]       2
# [\nFull leather, Red\n]         1
# [\nOther, Brown\n]              1
# [\nCloth, Orange\n]             1
# [\nFull leather, White\n]       1
# Name: Upholstery, dtype: int64

# %%
df['Nr. of Doors'].describe()
# Out:
# count       15707
# unique          6
# top       [\n5\n]
# freq        11575
# Name: Nr. of Doors, dtype: object

# %%
df['Nr. of Doors'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n5\n]    11575
# [\n4\n]     3079
# [\n3\n]      832
# [\n2\n]      219
# [\n7\n]        1
# [\n1\n]        1
# Name: Nr. of Doors, dtype: int64

# %%
df['Nr. of Seats'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n5\n]    13336
# [\n4\n]     1125
# [\n7\n]      362
# [\n2\n]      116
# [\n6\n]        2
# [\n3\n]        1
# Name: Nr. of Seats, dtype: int64

# %%
df['Gearing Type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Manual, \n]            8153
# [\n, Automatic, \n]         7297
# [\n, Semi-automatic, \n]     469
# Name: Gearing Type, dtype: int64

# %%
df.Gears.describe()
# Out:
# count       11207
# unique         10
# top       [\n6\n]
# freq         5822
# Name: Gears, dtype: object

# %%
df.Gears.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n6\n]     5822
# [\n5\n]     3239
# [\n7\n]     1908
# [\n8\n]      224
# [\n9\n]        6
# [\n4\n]        2
# [\n3\n]        2
# [\n1\n]        2
# [\n50\n]       1
# [\n2\n]        1
# Name: Gears, dtype: int64

# %%
df.Displacement.describe()
# Out:
# count              15423
# unique                77
# top       [\n1,598 cc\n]
# freq                4761
# Name: Displacement, dtype: object

# %%
df.Cylinders.describe()
# Out:
# count       10239
# unique          7
# top       [\n4\n]
# freq         8105
# Name: Cylinders, dtype: object

# %%
df.Cylinders.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n4\n]    8105
# [\n3\n]    2104
# [\n5\n]      22
# [\n6\n]       3
# [\n2\n]       2
# [\n8\n]       2
# [\n1\n]       1
# Name: Cylinders, dtype: int64

# %%
df.Weight.describe()
# Out:
# count               8945
# unique               434
# top       [\n1,163 kg\n]
# freq                 574
# Name: Weight, dtype: object

# %%
df['Drive chain'].describe()
# Out:
# count            9061
# unique              3
# top       [\nfront\n]
# freq             8886
# Name: Drive chain, dtype: object

# %%
df['Drive chain'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nfront\n]    8886
# [\n4WD\n]       171
# [\nrear\n]        4
# Name: Drive chain, dtype: int64

# %%
df.Fuel.describe()
# Out:
# count                                     15919
# unique                                       77
# top       [\n, Diesel (Particulate Filter), \n]
# freq                                       4315
# Name: Fuel, dtype: object

# %%
df['Consumption'].describe()
# Out:
# count                                                 14013
# unique                                                  881
# top       [[3.9 l/100 km (comb)], [4.1 l/100 km (city)],...
# freq                                                    304
# Name: Consumption, dtype: object

# %%
df['Consumption'].iloc[3]
# Out:
# [['3.8 l/100 km (comb)'], ['4.3 l/100 km (city)'], ['3.5 l/100 km (country)']]

# %%
df['CO2 Emission'].describe()
# Out:
# count                         14111
# unique                          123
# top       [\n120 g CO2/km (comb)\n]
# freq                            740
# Name: CO2 Emission, dtype: object

# %%
df['Emission Class'].describe()
# Out:
# count            12898
# unique               7
# top       [\nEuro 6\n]
# freq             10139
# Name: Emission Class, dtype: object

# %%
df['Emission Class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nEuro 6\n]          10139
# [\nEuro 6d-TEMP\n]     1845
# [[], [], []]            607
# [\nEuro 6c\n]           127
# [\nEuro 5\n]             78
# [\nEuro 6d\n]            62
# [\nEuro 4\n]             40
# Name: Emission Class, dtype: int64

# %%
df['\nComfort & Convenience\n'].describe()
# Out:
# count                                                 14999
# unique                                                 6198
# top       [Air conditioning, Electrical side mirrors, Hi...
# freq                                                    216
# Name: \nComfort & Convenience\n, dtype: object

# %%
df['\nEntertainment & Media\n'].describe()
# Out:
# count                                                 14545
# unique                                                  346
# top       [Bluetooth, Hands-free equipment, On-board com...
# freq                                                   1282
# Name: \nEntertainment & Media\n, dtype: object

# %%
df['\nExtras\n'].describe()
# Out:
# count              12957
# unique               659
# top       [Alloy wheels]
# freq                3245
# Name: \nExtras\n, dtype: object

# %%
df['\nSafety & Security\n'].describe()
# Out:
# count                                                 14937
# unique                                                 4443
# top       [ABS, Central door lock, Daytime running light...
# freq                                                    538
# Name: \nSafety & Security\n, dtype: object

# %%
df.description.describe()
# Out:
# count     15919
# unique    12874
# top          []
# freq        636
# Name: description, dtype: object

# %%
# Out:
# 0

# %% [markdown]
# ### Things Needs to Be Done
#
# 1. Think about removing url column.
# 2. **Get rid of the column "make_model"**
# 3. **short description
# 4. Body_type : There are 60 nulls values that we have to deal with.
# 5. Be aware of outliers such as min. in price column.
# 6. Vat column : Change it to deductible or not deductible
# 7. For the km column remove the "km" from the rows and change the data type to int or float.
# 8. **Drop the registration column because there is another registratio colum which only contains years.**
# 9. **From prev_owner column remove the part of "previous owner" and change data type to integer. There are 6828 null values.Remove the "Previous owners" column.**
# 10. **Drop the column "kW"**
# 11. Change the "hp" column name to kW.Change the data type.
# 12. Clean the "Type" column.
# 13. **Drop the columns about inspectation.**
# 14. Come back to the Warranty column
# 15. **Drop the Full service column.**
# 16. **Drop the Non_smoking column.**
# 17. **Drop the null column.**
# 18. Clean both make and model columns.
# 19. Come back to the offer number column again.
# 20. Change the First registration column name as Registration year
# 21. **Drop the Body color original**
# 22. Organize Upholstery column
# 23. **Drop the Body column.**
# 24. Check the number of doors
# 25. For the number od seats, clean '\n'
# 26. **Drop the model code number  column**
# 27. Clean the outliers for gearing type column
# 28. For the Cyclinder column clean the outliers.
# 29. **You might drop Weight column(!)**
# 30. Make the small groups for Fuel column.
# 31. We might need the 'Consumption' to be in 3 different column.
# 32. For the CO2 Emission, get rid of the unnecessary string parts and change the column name.
# 33. For the Emission Class column be aware of empty brackets which are null valus and get rid of unnecessary inf.
# 34. Come back to the \nComfort & Convenience\n column.
# 35. Come back to '\nEntertainment & Media\n' column.
# 36. Extras column*
# 37. Safety & Security column*
# 38. **Drop the description column.**
# 39. **Drop the emission column.**
# 40. Gears column*
# 41. **Drop rest of the columns.**

# %%
df.sample(3).T
# Out:
#                                                                            6788   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                                      1.6 CDTi Dynamic (110 CV)
# body_type                                                                Compact
# price                                                                      12955
# vat                                                                         None
# km                                                                     37,527 km
# registration                                                             04/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                    [\n, \n, \n97 g CO2/km (comb)\n]
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                       [\n8816JYB\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                           [\nBlack\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,360 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.7 l/100 km (comb)], [4.2 l/100 km (city)],...
# CO2 Emission                                            [\n97 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Navigation system, Park Distance Control, Par...
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n                                                        NaN
# description                    [\n, 8816JYB, Oferta de financiación, consulta...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            13741  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                        IV Start R/CD COLOR ZV GARANTIE 04.2021
# body_type                                                                Compact
# price                                                                       6800
# vat                                                                         None
# km                                                                     34,000 km
# registration                                                             04/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         54 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                      \n03/2021\n
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n133 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                          [\nWEISS GLACIER\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,149 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.6 l/100 km (comb)], [7.2 l/100 km (city)],...
# CO2 Emission                                           [\n133 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Cruise control, Electrical side mirrors, Powe...
# \nEntertainment & Media\n                                     [CD player, Radio]
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Clio mit Renault Werksgarantie bis 04.202...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            9260
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                                    "1 4 66kW (90CV) Selective"
# body_type                                                                Compact
# price                                                                       8490
# vat                                                                         None
# km                                                                     34,164 km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n24 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                          [\nf764f8d5-c4f6-4439-9bd5-95325fb1323f\n]
# First Registration                                                           NaN
# Body Color                                                        [\n, Blue, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                   [\nAzul\n]
# Upholstery                                                                   NaN
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,163 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.2 l/100 km (comb)], [6.9 l/100 km (city)],...
# CO2 Emission                                           [\n120 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n                                                    NaN
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n                                                        NaN
# description                    [\n"VehÃ­culo certificado con el Sello Oficial...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %%
df1 = df.copy()

# %%
df1.drop('url', axis = 1, inplace = True)
df1.drop('make_model', axis = 1, inplace = True)
df1.drop('short_description', axis = 1, inplace = True)
df1.drop('kW', axis = 1, inplace = True)
df1.drop('registration', axis = 1, inplace = True)
df1.drop('Previous Owners', axis = 1, inplace = True)
df1.drop('Next Inspection', axis = 1, inplace = True)
df1.drop('Inspection new', axis = 1, inplace = True)
df1.drop('Full Service', axis = 1, inplace = True)
df1.drop('null', axis = 1, inplace = True)
df1.drop('Body Color Original', axis = 1, inplace = True)
df1.drop('Body', axis = 1, inplace = True)
df1.drop('Model Code', axis = 1, inplace = True)
df1.drop('Weight', axis = 1, inplace = True)
df1.drop('description', axis = 1, inplace = True)
df1.drop('Emission Label', axis = 1, inplace = True)
df1.drop('Country version', axis = 1, inplace = True)
df1.drop('Electricity consumption', axis = 1, inplace = True)
df1.drop('Last Service Date', axis = 1, inplace = True)
df1.drop('Other Fuel Types', axis = 1, inplace = True)
df1.drop('Availability', axis = 1, inplace = True)
df1.drop('Last Timing Belt Service Date', axis = 1, inplace = True)
df1.drop('Available from', axis = 1, inplace = True)
df1.drop('Non-smoking Vehicle', axis = 1, inplace = True)

# %%
df1.drop('Offer Number', axis = 1, inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   body_type                15859 non-null  object
#  1   price                    15919 non-null  int64
#  2   vat                      11406 non-null  object
#  3   km                       15919 non-null  object
#  4   prev_owner               9091 non-null   object
#  5   hp                       15919 non-null  object
#  6   Type                     15917 non-null  object
#  7   Warranty                 10499 non-null  object
#  8   Make                     15919 non-null  object
#  9   Model                    15919 non-null  object
#  10  Offer Number             12744 non-null  object
#  11  First Registration       14322 non-null  object
#  12  Body Color               15322 non-null  object
#  13  Paint Type               10147 non-null  object
#  14  Upholstery               12199 non-null  object
#  15  Nr. of Doors             15707 non-null  object
#  16  Nr. of Seats             14942 non-null  object
#  17  Gearing Type             15919 non-null  object
#  18  Displacement             15423 non-null  object
#  19  Cylinders                10239 non-null  object
#  20  Drive chain              9061 non-null   object
#  21  Fuel                     15919 non-null  object
#  22  Consumption              14013 non-null  object
#  23  CO2 Emission             14111 non-null  object
#  24  Emission Class           12898 non-null  object
#  25
# Comfort & Convenience
#   14999 non-null  object
#  26
# Entertainment & Media
#   14545 non-null  object
#  27
# Extras
#                  12957 non-null  object
#  28
# Safety & Security
#       14937 non-null  object
#  29  Gears                    11207 non-null  object
# dtypes: int64(1), object(29)
# memory usage: 3.6+ MB

# %%
df1.body_type.describe()
# Out:
# count      15859
# unique         9
# top       Sedans
# freq        7903
# Name: body_type, dtype: object

# %%
df1.body_type.unique()
# Out:
# array(['Sedans', 'Station wagon', 'Compact', 'Other', 'Coupe', 'Van',
#        'Off-Road', 'Convertible', None, 'Transporter'], dtype=object)

# %%
df1.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914         - km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918         - km
# Name: km, Length: 15919, dtype: object

# %%
df3 = df.copy()

# %%
df3.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914         - km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918         - km
# Name: km, Length: 15919, dtype: object

# %%
df3.km = df3.km.astype('str').replace('- km', np.nan)

# %%
df3.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914          NaN
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918          NaN
# Name: km, Length: 15919, dtype: object

# %%
df3.km  = df3.km.str.strip(" km")

# %%
df3.km = df3.km.str.replace(",", "")

# %%
df3.km
# Out:
# 0        56013
# 1        80000
# 2        83450
# 3        73000
# 4        16200
#          ...
# 15914      NaN
# 15915     9900
# 15916       15
# 15917       10
# 15918      NaN
# Name: km, Length: 15919, dtype: object

# %%
df3.km = df3.km.astype(float)

# %%
df3.km
# Out:
# 0        56013.0
# 1        80000.0
# 2        83450.0
# 3        73000.0
# 4        16200.0
#           ...
# 15914        NaN
# 15915     9900.0
# 15916       15.0
# 15917       10.0
# 15918        NaN
# Name: km, Length: 15919, dtype: float64

# %%
df1.km = df3.km

# %%
df[df.km == "- km"].sample(3).T
# Out:
#                                                                            14759  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                                     TCe 12V 75 CV 5 porte Life
# body_type                                                                 Sedans
# price                                                                      11200
# vat                                                                         None
# km                                                                          - km
# registration                                                             03/2019
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         56 kW
# Type                                              [, Pre-registered, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n24 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                      [\n11312976\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                       [\nUni/basic\n]
# Body Color Original                                                 [\nBianco\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n898 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,165 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.2 l/100 km (comb)], [6.5 l/100 km (city)],...
# CO2 Emission                                           [\n118 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Leather ste...
# \nEntertainment & Media\n                           [Bluetooth, MP3, Radio, USB]
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nALZACRISTALLI ELETTRICI, CERCHI FLEXWHEEL D...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1913   \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                      Sportback 30 TFSI 85(116) kW(PS) S tronic
# body_type                                                                Compact
# price                                                                      28755
# vat                                                               VAT deductible
# km                                                                          - km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                                         [, New, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                     [\nGSB338-Q2\n]
# First Registration                                                           NaN
# Body Color                                                        [\n, Blue, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                          [\nFirmamentblau\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                                 NaN
# Model Code                                                        [\n0588/BNO\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,200 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[4.8 l/100 km (comb)], [5.9 l/100 km (city)],...
# CO2 Emission                                           [\n110 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Electrical side mi...
# \nEntertainment & Media\n                      [Bluetooth, Hands-free equipment]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [Daytime running lights, Driver-side airbag, E...
# description                    [\n, Ausstattungspakete:,  Lichtpaket, Nichtra...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            5638
# url                            https://www.autoscout24.com//offers/audi-a3-1-...
# make_model                                                               Audi A3
# short_description                            1.5 TFSI Sportback PDC SH MMI Xenon
# body_type                                                          Station wagon
# price                                                                      22450
# vat                                                               VAT deductible
# km                                                                          - km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                                                         [, New, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                                 NaN
# First Registration                                                           NaN
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                [\nSchwarz\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BHX\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,498 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5 l/100 km (comb)], [6.3 l/100 km (city)], [...
# CO2 Emission                                           [\n114 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                                [Radio]
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, - seit über 50 Jahren Opel-Partner, - Ver...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                    [\nDenmark\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                       \nin 150 days from ordering\n
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df3.kw
# Out:
# 0         66 kW
# 1        141 kW
# 2         85 kW
# 3         66 kW
# 4         66 kW
#           ...
# 15914    147 kW
# 15915    165 kW
# 15916    146 kW
# 15917    147 kW
# 15918    165 kW
# Name: kw, Length: 15919, dtype: object

# %%
df1.rename(columns={'hp':'k'}, inplace = True )

# %%
df1.hp = df3.kW

# %%
df3.kw
# Out:
# 0         66 kW
# 1        141 kW
# 2         85 kW
# 3         66 kW
# 4         66 kW
#           ...
# 15914    147 kW
# 15915    165 kW
# 15916    146 kW
# 15917    147 kW
# 15918    165 kW
# Name: kw, Length: 15919, dtype: object

# %%
df1.kW = df3.kw

# %%
df1.kW
# Out:
# 0         66 kW
# 1        141 kW
# 2         85 kW
# 3         66 kW
# 4         66 kW
#           ...
# 15914    147 kW
# 15915    165 kW
# 15916    146 kW
# 15917    147 kW
# 15918    165 kW
# Name: kW, Length: 15919, dtype: object

# %%
df1.sample(3).T
# Out:
#                                                                         5551  \
# body_type                                                             Sedans
# price                                                                  22900
# vat                                                           VAT deductible
# km                                                                      50.0
# prev_owner                                                              None
# kW                                                                     85 kW
# Type                                                    [, Used, , Gasoline]
# Warranty                                                       \n24 months\n
# Make                                                                \nAudi\n
# Model                                                           [\n, A3, \n]
# Offer Number                                                    [\n514410\n]
# First Registration                                            [\n, 2019, \n]
# Body Color                                                   [\n, White, \n]
# Paint Type                                                               NaN
# Upholstery                                                               NaN
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                    [\n999 cc\n]
# Cylinders                                                            [\n3\n]
# Drive chain                                                              NaN
# Fuel                                                      [\n, Gasoline, \n]
# Consumption                [[5 l/100 km (comb)], [5.6 l/100 km (city)], [...
# CO2 Emission                                       [\n118 g CO2/km (comb)\n]
# Emission Class                                                           NaN
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                         [On-board computer, Radio]
# \nExtras\n                     [Alloy wheels, Sport seats, Sport suspension]
# \nSafety & Security\n      [ABS, Driver-side airbag, Electronic stability...
# Gears                                                                [\n6\n]
#
#                                                                         7328  \
# body_type                                                             Sedans
# price                                                                  15270
# vat                                                           VAT deductible
# km                                                                   25350.0
# prev_owner                                                  1 previous owner
# kW                                                                     92 kW
# Type                               [, Used, , Super 95 / Regular/Benzine 91]
# Warranty                                                                 NaN
# Make                                                                \nOpel\n
# Model                                                        [\n, Astra, \n]
# Offer Number                                                     [\nB76-5\n]
# First Registration                                            [\n, 2018, \n]
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,399 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                 [\n, Super 95 / Regular/Benzine 91, \n]
# Consumption                [\n, 5.5 l/100 km (comb), \n, 7.3 l/100 km (ci...
# CO2 Emission                                       [\n128 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n  [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                 [Alloy wheels, Sport seats, Touch screen, Voic...
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                [\n6\n]
#
#                                                                         4794
# body_type                                                             Sedans
# price                                                                  21150
# vat                                                           VAT deductible
# km                                                                   10700.0
# prev_owner                                                  1 previous owner
# kW                                                                     85 kW
# Type                                                    [, Used, , Super 95]
# Warranty                                          [\n, \n, \nEuro 6d-TEMP\n]
# Make                                                                \nAudi\n
# Model                                                           [\n, A3, \n]
# Offer Number                                                    [\n108204\n]
# First Registration                                            [\n, 2018, \n]
# Body Color                                                   [\n, Black, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n4\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                    [\n999 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                      [\nfront\n]
# Fuel                                                      [\n, Super 95, \n]
# Consumption                [[4.7 l/100 km (comb)], [5.7 l/100 km (city)],...
# CO2 Emission                                       [\n107 g CO2/km (comb)\n]
# Emission Class                                            [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                            [Alloy wheels, Roof rack, Sport seats]
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                [\n6\n]

# %%
df1.kW = df1.kW.str.strip(' kW')

# %%
df1.kW
# Out:
# 0         66
# 1        141
# 2         85
# 3         66
# 4         66
#         ...
# 15914    147
# 15915    165
# 15916    146
# 15917    147
# 15918    165
# Name: kW, Length: 15919, dtype: object

# %%
df1.kW.sample(5)
# Out:
# 10735    125
# 14527     56
# 2266      70
# 9611      55
# 6483      70
# Name: kW, dtype: object

# %%
df1.kW = df1.kW.replace(0,np.nan)

# %%
df1.kW = df1.kW.astype(float)

# %%
df1.kW
# Out:
# 0         66.0
# 1        141.0
# 2         85.0
# 3         66.0
# 4         66.0
#          ...
# 15914    147.0
# 15915    165.0
# 15916    146.0
# 15917    147.0
# 15918    165.0
# Name: kW, Length: 15919, dtype: float64

# %%
df1.kW.isnull().value_counts()
# Out:
# False    15831
# True        88
# Name: kW, dtype: int64

# %%
df1.prev_owner
# Out:
# 0        2 previous owners
# 1                     None
# 2         1 previous owner
# 3         1 previous owner
# 4         1 previous owner
#                ...
# 15914                 None
# 15915     1 previous owner
# 15916     1 previous owner
# 15917                 None
# 15918     1 previous owner
# Name: prev_owner, Length: 15919, dtype: object

# %%
df1.prev_owner = df1.prev_owner.str.strip(' previous owner')

# %%
df1.prev_owner
# Out:
# 0           2
# 1        None
# 2           1
# 3           1
# 4           1
#          ...
# 15914    None
# 15915       1
# 15916       1
# 15917    None
# 15918       1
# Name: prev_owner, Length: 15919, dtype: object

# %%
df1.prev_owner = df1.prev_owner.astype(float)

# %%
df1.prev_owner
# Out:
# 0        2.0
# 1        NaN
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 15914    NaN
# 15915    1.0
# 15916    1.0
# 15917    NaN
# 15918    1.0
# Name: prev_owner, Length: 15919, dtype: float64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   body_type                15859 non-null  object
#  1   price                    15919 non-null  int64
#  2   vat                      11406 non-null  object
#  3   km                       14895 non-null  float64
#  4   prev_owner               9091 non-null   float64
#  5   kW                       15831 non-null  float64
#  6   Type                     15917 non-null  object
#  7   Warranty                 10499 non-null  object
#  8   Make                     15919 non-null  object
#  9   Model                    15919 non-null  object
#  10  Offer Number             12744 non-null  object
#  11  First Registration       14322 non-null  object
#  12  Body Color               15322 non-null  object
#  13  Paint Type               10147 non-null  object
#  14  Upholstery               12199 non-null  object
#  15  Nr. of Doors             15707 non-null  object
#  16  Nr. of Seats             14942 non-null  object
#  17  Gearing Type             15919 non-null  object
#  18  Displacement             15423 non-null  object
#  19  Cylinders                10239 non-null  object
#  20  Drive chain              9061 non-null   object
#  21  Fuel                     15919 non-null  object
#  22  Consumption              14013 non-null  object
#  23  CO2 Emission             14111 non-null  object
#  24  Emission Class           12898 non-null  object
#  25
# Comfort & Convenience
#   14999 non-null  object
#  26
# Entertainment & Media
#   14545 non-null  object
#  27
# Extras
#                  12957 non-null  object
#  28
# Safety & Security
#       14937 non-null  object
#  29  Gears                    11207 non-null  object
# dtypes: float64(3), int64(1), object(26)
# memory usage: 3.6+ MB

# %% [markdown]
# ### Things Needs to Be Done
#
# 1. Think about removing url column.
# 2. **Get rid of the column "make_model"**
# 3. **short description
# 4. Body_type : There are 60 nulls values that we have to deal with.
# 5. Be aware of outliers such as min. in price column.
# 6. Vat column : Change it to deductible or not deductible
# 7. For the km column remove the "km" from the rows and change the data type to int or float.
# 8. **Drop the registration column because there is another registratio colum which only contains years.**
# 9. **From prev_owner column remove the part of "previous owner" and change data type to integer. There are 6828 null values.Remove the "Previous owners" column.**
# 10. **Drop the column "kW"**
# 11. Change the "hp" column name to kW.Change the data type.
# 12. Clean the "Type" column.
# 13. **Drop the columns about inspectation.**
# 14. Come back to the Warranty column
# 15. **Drop the Full service column.**
# 16. **Drop the Non_smoking column.**
# 17. **Drop the null column.**
# 18. Clean both make and model columns.
# 19. Come back to the offer number column again.
# 20. Change the First registration column name as Registration year
# 21. **Drop the Body color original**
# 22. Organize Upholstery column
# 23. **Drop the Body column.**
# 24. Check the number of doors
# 25. For the number od seats, clean '\n'
# 26. **Drop the model code number  column**
# 27. Clean the outliers for gearing type column
# 28. For the Cyclinder column clean the outliers.
# 29. **You might drop Weight column(!)**
# 30. Make the small groups for Fuel column.
# 31. We might need the 'Consumption' to be in 3 different column.
# 32. For the CO2 Emission, get rid of the unnecessary string parts and change the column name.
# 33. For the Emission Class column be aware of empty brackets which are null valus and get rid of unnecessary inf.
# 34. Come back to the \nComfort & Convenience\n column.
# 35. Come back to '\nEntertainment & Media\n' column.
# 36. Extras column*
# 37. Safety & Security column*
# 38. **Drop the description column.**
# 39. **Drop the emission column.**
# 40. Gears column*
# 41. **Drop rest of the columns.**

# %%
df1.Type
# Out:
# 0                  [, Used, , Diesel (Particulate Filter)]
# 1                                     [, Used, , Gasoline]
# 2                  [, Used, , Diesel (Particulate Filter)]
# 3                  [, Used, , Diesel (Particulate Filter)]
# 4                  [, Used, , Diesel (Particulate Filter)]
#                                ...
# 15914               [, New, , Diesel (Particulate Filter)]
# 15915    [, Used, , Super 95 / Super Plus 98 (Particula...
# 15916                         [, Pre-registered, , Diesel]
# 15917                         [, Pre-registered, , Diesel]
# 15918                        [, Demonstration, , Super 95]
# Name: Type, Length: 15919, dtype: object

# %%
df3.Model
# Out:
# 0            [\n, A1, \n]
# 1            [\n, A1, \n]
# 2            [\n, A1, \n]
# 3            [\n, A1, \n]
# 4            [\n, A1, \n]
#                ...
# 15914    [\n, Espace, \n]
# 15915    [\n, Espace, \n]
# 15916    [\n, Espace, \n]
# 15917    [\n, Espace, \n]
# 15918    [\n, Espace, \n]
# Name: Model, Length: 15919, dtype: object

# %%
df3.Model[:][1]
# Out:
# ['\n', 'A1', '\n']

# %%
df3.Make
# Out:
# 0           \nAudi\n
# 1           \nAudi\n
# 2           \nAudi\n
# 3           \nAudi\n
# 4           \nAudi\n
#             ...
# 15914    \nRenault\n
# 15915    \nRenault\n
# 15916    \nRenault\n
# 15917    \nRenault\n
# 15918    \nRenault\n
# Name: Make, Length: 15919, dtype: object

# %%
df2 = df1.copy()

# %%
df2.Make = df2.Make.str.strip('\n')

# %%
df1.Make = df2.Make

# %%
df1.Make
# Out:
# 0           Audi
# 1           Audi
# 2           Audi
# 3           Audi
# 4           Audi
#           ...
# 15914    Renault
# 15915    Renault
# 15916    Renault
# 15917    Renault
# 15918    Renault
# Name: Make, Length: 15919, dtype: object

# %%
df3.Model
# Out:
# 0            [\n, A1, \n]
# 1            [\n, A1, \n]
# 2            [\n, A1, \n]
# 3            [\n, A1, \n]
# 4            [\n, A1, \n]
#                ...
# 15914    [\n, Espace, \n]
# 15915    [\n, Espace, \n]
# 15916    [\n, Espace, \n]
# 15917    [\n, Espace, \n]
# 15918    [\n, Espace, \n]
# Name: Model, Length: 15919, dtype: object

# %%
#for i in df3.Model:
    #print(i[1])

# %%
df2.Model.strip('\n')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-380-b6174bc766b6> in <module>
# ----> 1 df2.Model.strip('\n')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
df3.Model
# Out:
# 0            [\n, A1, \n]
# 1            [\n, A1, \n]
# 2            [\n, A1, \n]
# 3            [\n, A1, \n]
# 4            [\n, A1, \n]
#                ...
# 15914    [\n, Espace, \n]
# 15915    [\n, Espace, \n]
# 15916    [\n, Espace, \n]
# 15917    [\n, Espace, \n]
# 15918    [\n, Espace, \n]
# Name: Model, Length: 15919, dtype: object

# %%
df3.Model=df3.Model.str[1].str.strip('\n')

# %%
df3.Model
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: Model, Length: 15919, dtype: object

# %%
df1.Model = df3.Model

# %%
df1.sample(3).T
# Out:
#                                                                        13387  \
# body_type                                                             Sedans
# price                                                                   9900
# vat                                                         Price negotiable
# km                                                                   51000.0
# prev_owner                                                               1.0
# kW                                                                      66.0
# Type                                 [, Used, , Diesel (Particulate Filter)]
# Warranty                                                                 NaN
# Make                                                                 Renault
# Model                                                                   Clio
# Offer Number                                                             NaN
# First Registration                                            [\n, 2017, \n]
# Body Color                                                   [\n, White, \n]
# Paint Type                                                               NaN
# Upholstery                                         [\nPart leather, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,461 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                              NaN
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# Consumption                [[3.3 l/100 km (comb)], [3.5 l/100 km (city)],...
# CO2 Emission                                        [\n85 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Electrical side mirrors, Le...
# \nEntertainment & Media\n                     [Bluetooth, On-board computer]
# \nExtras\n                                                    [Alloy wheels]
# \nSafety & Security\n      [ABS, Alarm system, Central door lock, Driver-...
# Gears                                                                [\n6\n]
#
#                                                                        15263  \
# body_type                                                                Van
# price                                                                  18480
# vat                                                                     None
# km                                                                  112300.0
# prev_owner                                                               1.0
# kW                                                                     147.0
# Type                                                    [, Used, , Gasoline]
# Warranty                             [\n6 months\n, \n140 g CO2/km (comb)\n]
# Make                                                                 Renault
# Model                                                                 Espace
# Offer Number                                                    [\nc061c3\n]
# First Registration                                            [\n, 2016, \n]
# Body Color                                                   [\n, White, \n]
# Paint Type                                                               NaN
# Upholstery                                                               NaN
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,618 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                              NaN
# Fuel                                                      [\n, Gasoline, \n]
# Consumption                [[6.2 l/100 km (comb)], [7.8 l/100 km (city)],...
# CO2 Emission                                       [\n140 g CO2/km (comb)\n]
# Emission Class                                                           NaN
# \nComfort & Convenience\n                                   [Cruise control]
# \nEntertainment & Media\n                                                NaN
# \nExtras\n                                                    [Alloy wheels]
# \nSafety & Security\n      [ABS, Driver-side airbag, Passenger-side airba...
# Gears                                                                    NaN
#
#                                                                        4247
# body_type                                                             Sedans
# price                                                                  18000
# vat                                                                     None
# km                                                                   31500.0
# prev_owner                                                               NaN
# kW                                                                      85.0
# Type                                                      [, Used, , Diesel]
# Warranty                                                                 NaN
# Make                                                                    Audi
# Model                                                                     A3
# Offer Number                                                             NaN
# First Registration                                            [\n, 2017, \n]
# Body Color                                                   [\n, White, \n]
# Paint Type                                                               NaN
# Upholstery                                                               NaN
# Nr. of Doors                                                         [\n3\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                              NaN
# Fuel                                                        [\n, Diesel, \n]
# Consumption                [[4 l/100 km (comb)], [4.5 l/100 km (city)], [...
# CO2 Emission                                       [\n106 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Seat ventilation, Split rea...
# \nEntertainment & Media\n                                 [Bluetooth, Radio]
# \nExtras\n                                                    [Alloy wheels]
# \nSafety & Security\n      [ABS, Adaptive Cruise Control, Alarm system, C...
# Gears                                                                [\n6\n]

# %%
df4 = df.copy()

# %%
df4.Model = df4.Model.str[1]

# %%
df4.Model
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: Model, Length: 15919, dtype: object

# %%
df1.Type
# Out:
# 0                  [, Used, , Diesel (Particulate Filter)]
# 1                                     [, Used, , Gasoline]
# 2                  [, Used, , Diesel (Particulate Filter)]
# 3                  [, Used, , Diesel (Particulate Filter)]
# 4                  [, Used, , Diesel (Particulate Filter)]
#                                ...
# 15914               [, New, , Diesel (Particulate Filter)]
# 15915    [, Used, , Super 95 / Super Plus 98 (Particula...
# 15916                         [, Pre-registered, , Diesel]
# 15917                         [, Pre-registered, , Diesel]
# 15918                        [, Demonstration, , Super 95]
# Name: Type, Length: 15919, dtype: object

# %%
df1.Type.describe()
# Out:
# count                                       15917
# unique                                        169
# top       [, Used, , Diesel (Particulate Filter)]
# freq                                         3475
# Name: Type, dtype: object

# %%
df1.Type.str[1].value_counts()
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: Type, dtype: int64

# %%
df3.Type = df1.Type.str[1]

# %%
df1.Type = df3.Type

# %%
df3.Type.value_counts()
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: Type, dtype: int64

# %%
df1.Warranty.describe()
# Out:
# count                    10499
# unique                     515
# top       [\n, \n, \nEuro 6\n]
# freq                      1868
# Name: Warranty, dtype: object

# %%
df3.Warranty
# Out:
# 0                 [\n, \n, \n4 (Green)\n]
# 1                                     NaN
# 2        [\n, \n, \n99 g CO2/km (comb)\n]
# 3                                     NaN
# 4                    [\n, \n, \nEuro 6\n]
#                        ...
# 15914                       \n24 months\n
# 15915                [\n, \n, \nEuro 6\n]
# 15916             [\n, \n, \n4 (Green)\n]
# 15917                                  \n
# 15918                                 NaN
# Name: Warranty, Length: 15919, dtype: object

# %%
df1.sample(3).T
# Out:
#                                                                        4569   \
# body_type                                                             Sedans
# price                                                                  23444
# vat                                                           VAT deductible
# km                                                                     100.0
# prev_owner                                                               1.0
# kW                                                                      85.0
# Type                                            [, Pre-registered, , Diesel]
# Warranty                                                [\n, \n, \nEuro 6\n]
# Make                                                                    Audi
# Model                                                                     A3
# First Registration                                            [\n, 2018, \n]
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                                        [\n, Diesel, \n]
# Consumption                [[3.9 l/100 km (comb)], [4.2 l/100 km (city)],...
# CO2 Emission                                       [\n103 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                                                    [Alloy wheels]
# \nSafety & Security\n      [Daytime running lights, Driver-side airbag, E...
# Gears                                                                    NaN
#
#                                                                        8044   \
# body_type                                                            Compact
# price                                                                  15816
# vat                                                                     None
# km                                                                       NaN
# prev_owner                                                               NaN
# kW                                                                      81.0
# Type                                                       [, New, , Diesel]
# Warranty                                                                 NaN
# Make                                                                    Opel
# Model                                                                  Astra
# First Registration                                                       NaN
# Body Color                                                               NaN
# Paint Type                                                               NaN
# Upholstery                                                               NaN
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                                        [\n, Diesel, \n]
# Consumption                [[3 l/100 km (comb)], [4 l/100 km (city)], [3 ...
# CO2 Emission                                                             NaN
# Emission Class                                                           NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nExtras\n                                                               NaN
# \nSafety & Security\n                                                    NaN
# Gears                                                                [\n6\n]
#
#                                                                        13075
# body_type                                                            Compact
# price                                                                  15590
# vat                                                           VAT deductible
# km                                                                   17229.0
# prev_owner                                                               1.0
# kW                                                                      87.0
# Type                       [, Used, , Super 95 / Super E10 95 / Super Plu...
# Warranty                                                                 NaN
# Make                                                                 Renault
# Model                                                                   Clio
# First Registration                                            [\n, 2018, \n]
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,197 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                       [\n, Super 95 / Super E10 95 / Super Plus 98, \n]
# Consumption                [\n, 5.5 l/100 km (comb), \n, 7 l/100 km (city...
# CO2 Emission                                       [\n125 g CO2/km (comb)\n]
# Emission Class                                                           NaN
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n  [Bluetooth, Digital radio, Hands-free equipmen...
# \nExtras\n                 [Alloy wheels, Catalytic Converter, Touch scre...
# \nSafety & Security\n      [ABS, Adaptive headlights, Central door lock w...
# Gears                                                                [\n6\n]

# %%
df3['Warranty'].str.contains("months").value_counts()
# Out:
# True     2057
# False     979
# Name: Warranty, dtype: int64

# %%
df1.drop('Warranty', axis = 1, inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   body_type                15859 non-null  object
#  1   price                    15919 non-null  int64
#  2   vat                      11406 non-null  object
#  3   km                       14895 non-null  float64
#  4   prev_owner               9091 non-null   float64
#  5   kW                       15831 non-null  float64
#  6   Type                     15917 non-null  object
#  7   Make                     15919 non-null  object
#  8   Model                    15919 non-null  object
#  9   First Registration       14322 non-null  object
#  10  Body Color               15322 non-null  object
#  11  Paint Type               10147 non-null  object
#  12  Upholstery               12199 non-null  object
#  13  Nr. of Doors             15707 non-null  object
#  14  Nr. of Seats             14942 non-null  object
#  15  Gearing Type             15919 non-null  object
#  16  Displacement             15423 non-null  object
#  17  Cylinders                10239 non-null  object
#  18  Drive chain              9061 non-null   object
#  19  Fuel                     15919 non-null  object
#  20  Consumption              14013 non-null  object
#  21  CO2 Emission             14111 non-null  object
#  22  Emission Class           12898 non-null  object
#  23
# Comfort & Convenience
#   14999 non-null  object
#  24
# Entertainment & Media
#   14545 non-null  object
#  25
# Extras
#                  12957 non-null  object
#  26
# Safety & Security
#       14937 non-null  object
#  27  Gears                    11207 non-null  object
# dtypes: float64(3), int64(1), object(24)
# memory usage: 3.4+ MB

# %%
df1.Type
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: Type, Length: 15919, dtype: object

# %%
df1.rename(columns={'Type':'Condition'}, inplace = True)

# %%
df1.rename(columns={'body_type':'Body_Type'}, inplace = True)
df1.rename(columns={'price':'Price'}, inplace = True)
df1.rename(columns={'vat':'Vat'}, inplace = True)
df1.rename(columns={'prev_owner':'Previous_Owner'}, inplace = True)
df1.rename(columns={'First Registration':'Registration_Year'}, inplace = True)
df1.rename(columns={'Body Color':'Body_Color'}, inplace = True)
df1.rename(columns={'Paint Type':'Paint_Type'}, inplace = True)
df1.rename(columns={'Nr. of Doors':'Nr_of_Doors'}, inplace = True)
df1.rename(columns={'Nr. of Seats':'Nr_of_Seats'}, inplace = True)
df1.rename(columns={'Gearing Type':'Gearing_Type'}, inplace = True)
df1.rename(columns={'CO2 Emission':'CO2_Emission'}, inplace = True)
df1.rename(columns={'Emission Class':'Emission_Class'}, inplace = True)
df1.rename(columns={'\nComfort & Convenience\n':'Comfort_Convenience'}, inplace = True)
df1.rename(columns={'\nEntertainment & Media\n':'Entertainment_Media'}, inplace = True)
df1.rename(columns={'\nExtras\n':'Extras'}, inplace = True)
df1.rename(columns={'\nSafety & Security\n':'Safety & Security'}, inplace = True)

# %%
df1.rename(columns={'Safety & Security':'Safety_Security'}, inplace = True)

# %%
df1.rename(columns={'Drive chain':'Drive_Chain'}, inplace = True)

# %%
df1.rename(columns={'km':'Km'}, inplace = True)

# %%
df1.sample(3).T
# Out:
#                                                                  10841  \
# Body_Type                                                Station wagon
# Price                                                             9980
# Vat                                                     VAT deductible
# Km                                                            155000.0
# Previous_Owner                                                     1.0
# kW                                                               100.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                         Insignia
# First_Registration                                      [\n, 2016, \n]
# Body_Color                                            [\n, Silver, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption                            [[5.1 l/100 km (comb)], [], []]
# CO2_Emission                                 [\n135 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                 [Catalytic Converter, Roof rack, Voice Control]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n6\n]
#
#                                                                  5962   \
# Body_Type                                                       Sedans
# Price                                                            13895
# Vat                                                               None
# Km                                                             57605.0
# Previous_Owner                                                     2.0
# kW                                                               100.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Astra
# First_Registration                                      [\n, 2016, \n]
# Body_Color                                             [\n, Black, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                           [\nCloth, Grey\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                        NaN
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[4.5 l/100 km (comb)], [5.7 l/100 km (city)],...
# CO2_Emission                                 [\n119 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras               [Alloy wheels, Touch screen, Trailer hitch, Vo...
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n6\n]
#
#                                                                  3536
# Body_Type                                                       Sedans
# Price                                                            16000
# Vat                                                               None
# Km                                                             94000.0
# Previous_Owner                                                     NaN
# kW                                                                81.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A3
# First_Registration                                      [\n, 2016, \n]
# Body_Color                                              [\n, Grey, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                        NaN
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[3.8 l/100 km (comb)], [4.5 l/100 km (city)],...
# CO2_Emission                                  [\n99 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Electrical side mi...
# Entertainment_Media           [CD player, MP3, On-board computer, USB]
# Extras                   [Alloy wheels, Sport seats, Sport suspension]
# Safety_Security      [ABS, Central door lock with remote control, D...
# Gears                                                          [\n6\n]

# %%
df1.First_Registration = df3['First Registration'].str[1]

# %%
df1.sample(3).T
# Out:
#                                                                   7934  \
# Body_Type                                                       Sedans
# Price                                                            17590
# Vat                                                     VAT deductible
# Km                                                                 5.0
# Previous_Owner                                                     NaN
# kW                                                                77.0
# Condition                                                          New
# Make                                                              Opel
# Model                                                            Astra
# First_Registration                                                 NaN
# Body_Color                                               [\n, Red, \n]
# Paint_Type                                                         NaN
# Upholstery                                                 [\nCloth\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                              [\n999 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                [\nfront\n]
# Fuel                                                [\n, Gasoline, \n]
# Consumption          [[4.7 l/100 km (comb)], [5.5 l/100 km (city)],...
# CO2_Emission                                 [\n107 g CO2/km (comb)\n]
# Emission_Class                                                     NaN
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media          [Hands-free equipment, On-board computer]
# Extras                                    [Alloy wheels, Touch screen]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n5\n]
#
#                                                                   8844  \
# Body_Type                                                      Compact
# Price                                                            13890
# Vat                                                     VAT deductible
# Km                                                              7110.0
# Previous_Owner                                                     1.0
# kW                                                                66.0
# Condition                                               Employee's car
# Make                                                              Opel
# Model                                                            Corsa
# First_Registration                                                2018
# Body_Color                                            [\n, Silver, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,398 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                [\nfront\n]
# Fuel                                            [\n, Super E10 95, \n]
# Consumption          [[6.6 l/100 km (comb)], [8.2 l/100 km (city)],...
# CO2_Emission                                 [\n150 g CO2/km (comb)\n]
# Emission_Class                                      [\nEuro 6d-TEMP\n]
# Comfort_Convenience  [Air conditioning, Cruise control, Electrical ...
# Entertainment_Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras                                    [Alloy wheels, Touch screen]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n6\n]
#
#                                                                   9149
# Body_Type                                                       Sedans
# Price                                                             8700
# Vat                                                   Price negotiable
# Km                                                             68000.0
# Previous_Owner                                                     NaN
# kW                                                                55.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Corsa
# First_Registration                                                2017
# Body_Color                                              [\n, Grey, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                        NaN
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                                       NaN
# Cylinders                                                          NaN
# Drive_Chain                                                [\nfront\n]
# Fuel                                                  [\n, Diesel, \n]
# Consumption                                                        NaN
# CO2_Emission                                                       NaN
# Emission_Class                                            [[], [], []]
# Comfort_Convenience  [Air conditioning, Hill Holder, Keyless centra...
# Entertainment_Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras               [Alloy wheels, Shift paddles, Sport package, T...
# Safety_Security      [ABS, Central door lock, Electronic stability ...
# Gears                                                          [\n5\n]

# %% [markdown]
# 1. Create age column.

# %% [markdown]
# ### Things Needs to Be Done
#
# 1. Think about removing url column.
# 2. **Get rid of the column "make_model"**
# 3. **short description
# 4. Body_type : There are 60 nulls values that we have to deal with.
# 5. Be aware of outliers such as min. in price column.
# 6. Vat column : Change it to deductible or not deductible
# 7. For the km column remove the "km" from the rows and change the data type to int or float.
# 8. **Drop the registration column because there is another registratio colum which only contains years.**
# 9. **From prev_owner column remove the part of "previous owner" and change data type to integer. There are 6828 null values.Remove the "Previous owners" column.**
# 10. **Drop the column "kW"**
# 11. Change the "hp" column name to kW.Change the data type.
# 12. Clean the "Type" column.
# 13. **Drop the columns about inspectation.**
# 14. Come back to the Warranty column
# 15. **Drop the Full service column.**
# 16. **Drop the Non_smoking column.**
# 17. **Drop the null column.**
# 18. Clean both make and model columns.
# 19. Come back to the offer number column again.
# 20. Change the First registration column name as Registration year
# 21. **Drop the Body color original**
# 22. Organize Upholstery column
# 23. **Drop the Body column.**
# 24. Check the number of doors
# 25. For the number od seats, clean '\n'
# 26. **Drop the model code number  column**
# 27. Clean the outliers for gearing type column
# 28. For the Cyclinder column clean the outliers.
# 29. **You might drop Weight column(!)**
# 30. Make the small groups for Fuel column.
# 31. We might need the 'Consumption' to be in 3 different column.
# 32. For the CO2 Emission, get rid of the unnecessary string parts and change the column name.
# 33. For the Emission Class column be aware of empty brackets which are null valus and get rid of unnecessary inf.
# 34. Come back to the \nComfort & Convenience\n column.
# 35. Come back to '\nEntertainment & Media\n' column.
# 36. Extras column*
# 37. Safety & Security column*
# 38. **Drop the description column.**
# 39. **Drop the emission column.**
# 40. Gears column*
# 41. **Drop rest of the columns.**

# %%
df1.Body_Color = df1.Body_Color.str[1]

# %%
df1.Body_Color.describe()
# Out:
# count     15322
# unique       14
# top       Black
# freq       3745
# Name: Body_Color, dtype: object

# %%
df1.Body_Color.isnull().sum()
# Out:
# 597

# %%
 a = df1.Upholstery

# %%
for i in a :
    if type(i) == list:
        print(i[0])
# Out:
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, White
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Grey
#
#
# Full leather
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Full leather, Red
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# alcantara, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Blue
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Red
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Grey
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Grey
#
#
# Cloth, Red
#
#
# alcantara, Black
#
#
# Cloth
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Blue
#
#
# Other, Black
#
#
# Cloth
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Velour, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Other
#
#
# Other
#
#
# Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Blue
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Part leather, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Velour, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Other
#
#
# Cloth
#
#
# Other, Other
#
#
# alcantara, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Velour, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Red
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Other, Other
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Blue
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather
#
#
# Cloth, Orange
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# alcantara, Black
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Velour
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Grey
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Velour
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Grey
#
#
# Other, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Other
#
#
# Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Grey
#
#
# Part leather, Grey
#
#
# Velour, Black
#
#
# Velour
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Full leather, Black
#
#
# Cloth, Other
#
#
# alcantara, Black
#
#
# alcantara, Black
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Blue
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Part leather, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# alcantara, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Grey
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Other, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Black
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Part leather
#
#
# Part leather
#
#
# Cloth, Black
#
#
# Velour
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Other, Other
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Other, Black
#
#
# Other, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Other, Grey
#
#
# Black
#
#
# Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Other, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Grey
#
#
# Other, Grey
#
#
# Cloth, Blue
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Blue
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Grey
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Full leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Velour
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# alcantara, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other
#
#
# Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Other
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Brown
#
#
# Grey
#
#
# alcantara, Grey
#
#
# Cloth, Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Black
#
#
# Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Other, Other
#
#
# Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Grey
#
#
# Cloth, Black
#
#
# alcantara, Other
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Full leather, Grey
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Other, Other
#
#
# alcantara, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# alcantara, Black
#
#
# Full leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Other
#
#
# Full leather, Black
#
#
# Black
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Grey
#
#
# Cloth, Black
#
#
# Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Full leather, Black
#
#
# Black
#
#
# Black
#
#
# Full leather, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Grey
#
#
# Grey
#
#
# alcantara, Black
#
#
# Grey
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Grey
#
#
# Part leather, Black
#
#
# Grey
#
#
# Grey
#
#
# Black
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Other
#
#
# Velour, Black
#
#
# Other
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Full leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Black
#
#
# Black
#
#
# Cloth, Grey
#
#
# Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Black
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Black
#
#
# Part leather
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Grey
#
#
# Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Grey
#
#
# Full leather, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Beige
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Cloth, Grey
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Grey
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Black
#
#
# Cloth
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Beige
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Black
#
#
# Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Grey
#
#
# Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Full leather, Black
#
#
# Grey
#
#
# Full leather, Other
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Velour, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# alcantara, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Brown
#
#
# Cloth, Black
#
#
# White
#
#
# Cloth, Black
#
#
# Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Grey
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather
#
#
# Part leather, Brown
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Part leather
#
#
# Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Grey
#
#
# Cloth, Grey
#
#
# Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Full leather, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Part leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Grey
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# alcantara, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather
#
#
# Part leather
#
#
# Part leather
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Other, Other
#
#
# Other, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Part leather, Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Full leather, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Other
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Full leather, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Grey
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Velour, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Other
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather
#
#
# Part leather
#
#
# Cloth, Grey
#
#
# Part leather
#
#
# Part leather
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Part leather
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Other
#
#
# Part leather, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Part leather, Other
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Part leather
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Full leather, Grey
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Full leather
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Cloth, Grey
#
#
# Part leather, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Brown
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, White
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Yellow
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather
#
#
# Full leather
#
#
# Full leather
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# ...
#
#
# Cloth
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth
#
#
# Cloth
#
#
# alcantara, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Black
#
#
# alcantara, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Part leather
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Other
#
#
# Other, Black
#
#
# Other, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Cloth, Grey
#
#
# Full leather, Grey
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Full leather, Grey
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Part leather, Brown
#
#
# Full leather, Brown
#
#
# Part leather
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Part leather, Brown
#
#
# Full leather, Other
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Full leather
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Full leather, Beige
#
#
# Part leather
#
#
# Full leather, Black
#
#
# Full leather
#
#
# Full leather
#
#
# Full leather, Grey
#
#
# Full leather, Black
#
#
# Part leather, Other
#
#
# Part leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Part leather, Brown
#
#
# Cloth, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Black
#
#
# Full leather
#
#
# Black
#
#
# Full leather, Other
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Part leather, Grey
#
#
# Part leather, Grey
#
#
# Part leather, Other
#
#
# Full leather, Other
#
#
# Part leather, Grey
#
#
# Full leather
#
#
# Cloth, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Part leather
#
#
# Part leather
#
#
# Part leather, Black
#
#
# Full leather, Black
#
#
# Part leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Full leather, Black
#
#
# Other, Grey
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Cloth, Other
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Other
#
#
# Cloth, Brown
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Other
#
#
# Part leather, Black
#
#
# Black
#
#
# Part leather, Brown
#
#
# Full leather
#
#
# Full leather, Black
#
#
# Part leather, Other
#
#
# Part leather, Grey
#
#
# Part leather, Other
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Brown
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Full leather, Black
#
#
# Cloth
#
#
# Full leather, Black
#
#
# Full leather, Brown
#
#
# Full leather, Other
#
#
# Full leather
#
#
# Other, Other
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Full leather, Grey
#
#
# Full leather, Grey
#
#
# Full leather, Grey
#
#
# Full leather, Grey
#
#
# Full leather, Beige
#
#
# Full leather, Grey
#
#
# Part leather, Brown
#
#
# Full leather, Grey
#
#
# Full leather, Black
#
#
# Brown
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Brown
#
#
# Full leather, Blue
#
#
# Part leather
#
#
# Part leather, Brown
#
#
# Full leather, Grey
#
#
# Full leather, Black
#
#
# Part leather, Brown
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Full leather, Other
#
#
# Full leather, Brown
#
#
# Part leather, Brown
#
#
# Full leather, Brown
#
#
# Cloth
#
#
# Full leather, Other
#
#
# Part leather
#
#
# Full leather, Black
#
#
# Part leather, Brown
#
#
# Part leather, Other
#
#
# Full leather, Black
#
#
# Part leather, Brown
#
#
# Full leather, Brown
#
#
# Grey
#
#
# Full leather, Grey
#
#
# Grey
#
#
# Full leather, Grey
#
#
# Full leather, Grey
#
#
# Part leather
#
#
# Grey
#
#
# Other, Other
#
#
# Other
#
#
# Part leather, Brown
#
#
# Part leather, Black
#
#
# Grey
#
#
# Full leather, Blue
#
#
# Full leather, Brown
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Black
#
#
# Full leather
#
#
# Grey
#
#
# Full leather, Other
#
#
# Part leather, Brown
#
#
# Grey
#
#
# Other, Other
#
#
# Full leather, Other
#
#
# Other, Other
#
#
# Full leather, Brown
#
#
# Part leather, Grey
#
#
# Other, Other
#
#
# Cloth, Black
#
#
# Part leather, Brown
#
#
# Part leather, Brown
#
#
# Full leather, Black
#
#
# Full leather, Grey
#
#
# Part leather, Brown
#
#
# Full leather, Grey
#
#
# Part leather, Brown
#
#
# Part leather, Grey
#
#
# Part leather, Black
#
#
# Part leather, Grey
#
#
# Full leather, Brown
#
#
# Part leather, Brown
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Brown
#
#
# Other, Other
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Grey
#
#
# Grey
#
#
# Grey
#
#
# Cloth, Grey
#
#
# Cloth, Brown
#
#
# Part leather, Brown
#
#
# Full leather, Black
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Full leather, Other
#
#
# Cloth, Black
#
#
# Full leather
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Cloth, Brown
#
#
# Cloth, Black
#
#
# Cloth, Grey
#
#
# Part leather
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Brown
#
#
# Part leather, Black
#
#
# Cloth
#
#
# Part leather
#
#
# Cloth
#
#
# Cloth, Grey
#
#
# Cloth, Brown
#
#
# Part leather, Black
#
#
# Part leather
#
#
# Part leather
#
#
# Full leather, Black
#
#
# Part leather, Brown
#
#
# Part leather, Brown
#
#
# Other
#
#
# Part leather
#
#
# Part leather, Brown
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Part leather
#
#
# Cloth, Brown
#
#
# Cloth, Grey
#
#
# Other, Brown
#
#
# Cloth, Black
#
#
# Part leather, Brown
#
#
# Part leather, Black
#
#
# Cloth, Grey
#
#
# Part leather, Black
#
#
# Part leather, Grey
#
#
# Cloth
#
#
# Cloth, Brown
#
#
# Cloth, Black
#
#
# Cloth
#
#
# Full leather, Black
#
#
# Cloth
#
#
# Part leather, Black
#
#
# alcantara, Black
#
#
# Full leather
#
#
# Full leather, Other
#
#
# Full leather, Other
#
#
# Full leather, Beige
#
#
# Full leather, White
#
#
# Part leather
#
#
# Black
#
#
# Full leather, Black
#
#
# Full leather
#
#
# Part leather, Brown
#
#
# Part leather
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Full leather, Black
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Black
#
#
# Part leather, Grey
#
#
# Part leather, Brown
#
#
# Part leather
#
#
# Full leather, Beige
#
#
# Cloth
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Other
#
#
# Part leather, Black
#
#
# Full leather, Other
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Black
#
#
# Full leather, Other
#
#
# Part leather, Other
#
#
# Cloth, Brown
#
#
# Full leather, Other
#
#
# Part leather
#
#
# Cloth, Brown
#
#
# Part leather
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Part leather, Brown
#
#
# Part leather, Black
#
#
# Brown
#
#
# Brown
#
#
# Full leather
#
#
# alcantara, Grey
#
#
# Full leather, Other
#
#
# Cloth
#
#
# Cloth
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Part leather, White
#
#
# Full leather, Brown
#
#
# Part leather
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Part leather
#
#
# Part leather, Grey
#
#
# Brown
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Full leather, Beige
#
#
# Full leather, Other
#
#
# Part leather, Black
#
#
# Full leather, Grey
#
#
# Part leather, Other
#
#
# Full leather, Grey
#
#
# Part leather, Black
#
#
# Other
#
#
# Part leather
#
#
# Full leather, Grey
#
#
# Full leather
#
#
# Part leather
#
#
# Part leather, Brown
#
#
# Part leather, Black
#
#
# Cloth
#
#
# Part leather
#
#
# Part leather
#
#
# Cloth
#
#
# Cloth, Black
#
#
# Full leather, Brown
#
#
# Part leather, Grey
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Part leather
#
#
# Full leather, Other
#
#
# Full leather, Other
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Brown
#
#
# Other
#
#
# Black
#
#
# Part leather, Black
#
#
# Brown
#
#
# Full leather
#
#
# Part leather, Black
#
#
# Brown
#
#
# Full leather, Brown
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Cloth, Brown
#
#
# Part leather, Black
#
#
# Part leather, Brown
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Brown
#
#
# Part leather, Brown
#
#
# Full leather
#
#
# Full leather, Beige
#
#
# Part leather, Other
#
#
# Part leather, Other
#
#
# Other
#
#
# Part leather, Black
#
#
# Cloth
#
#
# Full leather
#
#
# Full leather
#
#
# Full leather, Other
#
#
# Full leather, Grey
#
#
# Cloth, Brown
#
#
# Part leather, Black
#
#
# White
#
#
# Part leather, Black
#
#
# Part leather, Black
#
#
# Part leather, Brown
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Cloth, Black
#
#
# Other, Black
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Part leather, Brown
#
#
# Other
#
#
# Full leather, Other
#
#
# Full leather, Beige
#
#
# Other
#
#
# Other
#
#
# Cloth, Other
#
#
# Full leather, Black
#
#
# Full leather
#
#
# Part leather, Black
#
#
# Full leather, Beige
#
#
# Part leather, Brown
#
#
# Full leather, Black
#
#
# Grey
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Full leather
#
#
# Part leather, Other
#
#
# Part leather, Other
#
#
# Part leather, Other
#
#
# Part leather
#
#
# Part leather
#
#
# Part leather, Other
#
#
# Part leather, Brown
#
#
# Cloth
#
#
# Part leather
#
#
# Full leather, Black
#
#
# Full leather, Other
#
#
# Cloth, Other
#
#
# Cloth, Other
#
#
# Black
#
#
# Part leather, Brown
#
#
# Part leather, Brown
#
#
# alcantara, Black
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Part leather, Black
#
#
# Full leather, Other
#
#
# Full leather, Brown
#
#
# Black
#
#
# Full leather, Black
#
#
# Full leather, Brown
#
#
# Full leather, Black
#
#
# Full leather, Brown
#
#
# Cloth, Brown
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Full leather, Grey
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Black
#
#
# Cloth
#
#
# Full leather, Black
#
#
# Cloth, Brown
#
#
# Full leather
#
#
# Full leather
#
#
# Full leather, Grey
#
#
# Full leather, Brown
#
#
# Full leather, Other
#
#
# Full leather
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Cloth
#
#
# Full leather, Grey
#
#
# Full leather, Other
#
#
# Part leather, Black
#
#
# Other, Black
#
#
# Full leather, Brown
#
#
# Full leather, Other
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Full leather, Black
#
#
# Other, Black
#
#
# Full leather, Black
#
#
# Full leather, Brown
#
#
# Full leather, Black
#
#
# Part leather, Brown
#
#
# Full leather, Black
#
#
# Full leather, Brown
#
#
# Black
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Full leather
#
#
# Full leather
#
#
# Full leather, Grey
#
#
# Full leather, Black
#
#
# Cloth, Other
#
#
# Full leather, Beige
#
#
# Full leather, Brown
#
#
# Full leather, Beige
#
#
# Cloth, Brown
#
#
# Part leather, Brown
#
#
# Cloth, Black
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Full leather, Black
#
#
# Full leather
#
#
# Full leather, Grey
#
#
# Full leather, Brown
#
#
# Cloth, Brown
#
#
# Cloth, Other
#
#
# Part leather, Brown
#
#
# Full leather, Grey
#
#
# Cloth, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Part leather, Black
#
#
# Full leather, Black
#
#
# Cloth, Brown
#
#
# Part leather, Brown
#
#
# Full leather, Beige
#
#
# Cloth, Brown
#
#
# Cloth, Brown
#
#
# Brown
#
#
# Full leather, Grey
#
#
# Full leather, Black
#
#
# Part leather
#
#
# Full leather, Beige
#
#
# Other, Black
#
#
# Part leather
#
#
# Part leather
#
#
# Part leather
#
#
# Full leather, Beige
#
#
# Full leather, Beige
#
#
# Full leather, Beige
#
#
# Full leather, Black
#
#
# Part leather, Black
#
#
# Cloth, Brown
#
#
# Part leather
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Grey
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Full leather
#
#
# Full leather
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Part leather
#
#
# Full leather
#
#
# Part leather
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Part leather
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Other, Other
#
#
# Cloth
#
#
# Cloth
#
#
# Part leather
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Part leather
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Full leather, Black
#
#
# Full leather, Grey
#
#
# Full leather, Other
#
#
# Cloth, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Black
#
#
# Full leather, Black
#
#
# Full leather, Grey
#
#
# Part leather, Brown
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Full leather, Black
#
#
# Full leather, Brown
#
#
# Full leather, Grey
#
#
# Part leather
#
#
# Full leather, Brown
#
#
# Part leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather, Grey
#
#
# Full leather, Other
#
#
# Full leather, Brown
#
#
# Part leather, Brown
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Part leather
#
#
# Full leather, Other
#
#
# Cloth, Brown
#
#
# Full leather, Other
#
#
# Brown
#
#
# Full leather, Grey
#
#
# Cloth
#
#
# Part leather
#
#
# Full leather, Brown
#
#
# Full leather, Black
#
#
# Part leather, Brown
#
#
# Part leather, Black
#
#
# Full leather, Brown
#
#
# Part leather
#
#
# Full leather, Black
#
#
# Full leather, Other
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Full leather, Grey
#
#
# Full leather, Brown
#
#
# Cloth
#
#
# Full leather, Brown
#
#
# Full leather, Grey
#
#
# Cloth, Other
#
#
# Full leather
#
#
# Full leather
#
#
# Full leather
#
#
# Full leather, Other
#
#
# Full leather
#
#
# Grey
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Full leather, Brown
#
#
# Full leather, Brown
#
#
# Full leather
#
#
# Brown
#
#
# Cloth, Other
#
#
# Cloth
#
#
# Full leather
#
#
# Full leather, Other
#
#
# Full leather, Grey
#
#
# Full leather, Brown
#
#
# Cloth
#
#
# Full leather, Black
#
#
# Part leather
#
#
# Full leather, Brown

# %%
df1["Upholstery"] = df1["Upholstery"].apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Upholstery
# Out:
# 0               \nCloth, Black\n
# 1                \nCloth, Grey\n
# 2               \nCloth, Black\n
# 3                            NaN
# 4               \nCloth, Black\n
#                   ...
# 15914                        NaN
# 15915                  \nCloth\n
# 15916    \nFull leather, Black\n
# 15917           \nPart leather\n
# 15918    \nFull leather, Brown\n
# Name: Upholstery, Length: 15919, dtype: object

# %%
df1.sample(3).T
# Out:
#                                                                  14388  \
# Body_Type                                                       Sedans
# Price                                                            18490
# Vat                                                               None
# Km                                                             10564.0
# Previous_Owner                                                     1.0
# kW                                                               164.0
# Condition                                                         Used
# Make                                                           Renault
# Model                                                             Clio
# First_Registration                                                2018
# Body_Color                                                         Red
# Paint_Type                                                    Metallic
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                    [\n4\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,618 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                                                [\n, Gasoline, \n]
# Consumption          [[5.9 l/100 km (comb)], [7.6 l/100 km (city)],...
# CO2_Emission                                 [\n140 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Cruise control, Electrical ...
# Entertainment_Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras               [Alloy wheels, Shift paddles, Sport package, S...
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN
#
#                                                                  8070   \
# Body_Type                                                       Sedans
# Price                                                            18758
# Vat                                                     VAT deductible
# Km                                                                 NaN
# Previous_Owner                                                     NaN
# kW                                                                77.0
# Condition                                                          New
# Make                                                              Opel
# Model                                                            Astra
# First_Registration                                                 NaN
# Body_Color                                                       White
# Paint_Type                                                   Uni/basic
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                        NaN
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,000 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                                                [\n, Gasoline, \n]
# Consumption                                                        NaN
# CO2_Emission                                              [[], [], []]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment_Media                     [Bluetooth, On-board computer]
# Extras                                                  [Alloy wheels]
# Safety_Security      [ABS, Central door lock, Driver-side airbag, E...
# Gears                                                          [\n5\n]
#
#                                                                  9456
# Body_Type                                                       Sedans
# Price                                                             8900
# Vat                                                               None
# Km                                                             69000.0
# Previous_Owner                                                     1.0
# kW                                                                66.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Corsa
# First_Registration                                                2017
# Body_Color                                                        Grey
# Paint_Type                                                    Metallic
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,398 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                                                [\n, Gasoline, \n]
# Consumption          [[5.1 l/100 km (comb)], [6.5 l/100 km (city)],...
# CO2_Emission                                 [\n120 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Electrical side mirrors, Le...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                                   [Alloy wheels, Voice Control]
# Safety_Security      [ABS, Adaptive Cruise Control, Central door lo...
# Gears                                                          [\n5\n]

# %%
df1.Upholstery.str[1]
# Out:
# 0          C
# 1          C
# 2          C
# 3        NaN
# 4          C
#         ...
# 15914    NaN
# 15915      C
# 15916      F
# 15917      P
# 15918      F
# Name: Upholstery, Length: 15919, dtype: object

# %%
df1.Upholstery = df1.Upholstery.str.strip("\n")

# %%
df1.Upholstery.value_counts()
# Out:
# Cloth, Black           5821
# Part leather, Black    1121
# Cloth                  1005
# Cloth, Grey             891
# Cloth, Other            639
# Full leather, Black     575
# Black                   491
# Grey                    273
# Other, Other            182
# Part leather            140
# Full leather            139
# Full leather, Brown     116
# Part leather, Grey      116
# Other, Black            110
# Full leather, Other      72
# Full leather, Grey       67
# Part leather, Other      65
# Other                    56
# Part leather, Brown      50
# alcantara, Black         47
# Full leather, Beige      36
# Velour, Black            36
# Cloth, Brown             28
# Velour                   16
# Other, Grey              15
# Cloth, Beige             13
# Brown                    12
# Cloth, Blue              12
# Cloth, White              8
# Velour, Grey              8
# alcantara, Grey           6
# Cloth, Red                5
# Other, Yellow             4
# Beige                     3
# Part leather, Red         3
# alcantara                 2
# White                     2
# Full leather, Blue        2
# alcantara, Other          2
# Part leather, White       2
# Blue                      2
# Part leather, Beige       2
# Full leather, White       1
# Cloth, Orange             1
# Full leather, Red         1
# Other, Brown              1
# Name: Upholstery, dtype: int64

# %%
df1.Paint_Type = df1["Paint_Type"].apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Paint_Type = df1.Paint_Type.str.strip('\n')

# %%
df1.Paint_Type
# Out:
# 0        Metallic
# 1             NaN
# 2        Metallic
# 3        Metallic
# 4        Metallic
#            ...
# 15914    Metallic
# 15915    Metallic
# 15916         NaN
# 15917         NaN
# 15918    Metallic
# Name: Paint_Type, Length: 15919, dtype: object

# %%
df1.Paint_Type.describe()
# Out:
# count        10147
# unique           3
# top       Metallic
# freq          9794
# Name: Paint_Type, dtype: object

# %%
df1.Paint_Type.isnull().sum()
# Out:
# 5772

# %%
df1.Paint_Type.value_counts()
# Out:
# Metallic       9794
# Uni/basic       347
# Perl effect       6
# Name: Paint_Type, dtype: int64

# %%
df1.Paint_Type
# Out:
# 0        Metallic
# 1             NaN
# 2        Metallic
# 3        Metallic
# 4        Metallic
#            ...
# 15914    Metallic
# 15915    Metallic
# 15916         NaN
# 15917         NaN
# 15918    Metallic
# Name: Paint_Type, Length: 15919, dtype: object

# %%
df1.Nr_of_Doors = df1.Nr_of_Doors.apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Nr_of_Doors = df1.Nr_of_Doors.str.strip('\n')

# %%
df1.Nr_of_Seats = df1.Nr_of_Seats.apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Nr_of_Seats = df1.Nr_of_Seats.str.strip('\n')

# %%
df1.sample(3).T
# Out:
#                                                                   6446  \
# Body_Type                                                       Sedans
# Price                                                            10980
# Vat                                                     VAT deductible
# Km                                                             67160.0
# Previous_Owner                                                     1.0
# kW                                                                81.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Astra
# First_Registration                                                2016
# Body_Color                                                         Red
# Paint_Type                                                         NaN
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                                    Manual
# Displacement                                                     1598
# Cylinders                                                          4.0
# Drive_Chain                                                      front
# Fuel                                                            Diesel
# Consumption          [[3.4 l/100 km (comb)], [3.9 l/100 km (city)],...
# CO2_Emission                                  [\n90 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras                             [Catalytic Converter, Touch screen]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n6\n]
#
#                                                                   4346  \
# Body_Type                                                       Sedans
# Price                                                            16990
# Vat                                                               None
# Km                                                            117000.0
# Previous_Owner                                                     NaN
# kW                                                                85.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A3
# First_Registration                                                2017
# Body_Color                                                       Black
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                                    Manual
# Displacement                                                     1598
# Cylinders                                                          4.0
# Drive_Chain                                                      front
# Fuel                                                            Diesel
# Consumption          [[4 l/100 km (comb)], [4.5 l/100 km (city)], [...
# CO2_Emission                                 [\n106 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Cruise control, Mu...
# Entertainment_Media              [Bluetooth, On-board computer, Radio]
# Extras                                                  [Alloy wheels]
# Safety_Security      [ABS, Alarm system, Central door lock, Driver-...
# Gears                                                          [\n6\n]
#
#                              1012
# Body_Type                  Sedans
# Price                       20490
# Vat                          None
# Km                        11570.0
# Previous_Owner                1.0
# kW                           70.0
# Condition                    Used
# Make                         Audi
# Model                          A1
# First_Registration           2017
# Body_Color                  Black
# Paint_Type                    NaN
# Upholstery                    NaN
# Nr_of_Doors                     5
# Nr_of_Seats                     4
# Gearing_Type            Automatic
# Displacement                 999
# Cylinders                     NaN
# Drive_Chain                   NaN
# Fuel                     Gasoline
# Consumption                   NaN
# CO2_Emission         [[], [], []]
# Emission_Class                NaN
# Comfort_Convenience           NaN
# Entertainment_Media           NaN
# Extras                        NaN
# Safety_Security               NaN
# Gears                     [\n7\n]

# %%
df1.Gearing_Type = df1.Gearing_Type.apply(lambda item: item[1] if type(item) == list else item)
df1.Gearing_Type = df1.Gearing_Type.str.strip('\n')

# %%
df1.Gearing_Type = df3["Gearing Type"].str[1]

# %%
df3['Gearing Type']
# Out:
# ['\n', 'Automatic', '\n']

# %%
df1.Gearing_Type = df1.Gearing_Type.str.strip('\n')

# %%
df1.Gearing_Type
# Out:
# 0        Automatic
# 1        Automatic
# 2        Automatic
# 3        Automatic
# 4        Automatic
#            ...
# 15914    Automatic
# 15915    Automatic
# 15916    Automatic
# 15917    Automatic
# 15918    Automatic
# Name: Gearing_Type, Length: 15919, dtype: object

# %%
df1.Displacement = df3.Displacement

# %%
df1.Displacement.apply(lambda item: item[0] if type(item) == list else item)
# Out:
# 0        \n1,422 cc\n
# 1        \n1,798 cc\n
# 2        \n1,598 cc\n
# 3        \n1,422 cc\n
# 4        \n1,422 cc\n
#              ...
# 15914    \n1,997 cc\n
# 15915    \n1,798 cc\n
# 15916    \n1,997 cc\n
# 15917    \n1,997 cc\n
# 15918    \n1,798 cc\n
# Name: Displacement, Length: 15919, dtype: object

# %%
df1.Displacement = df1.Displacement.str[0].str.strip('\n').str.strip('cc')

# %%
df1.Displacement.value_counts()
# Out:
# 1,598      4761
# 999        2438
# 1,398      1314
# 1,399       749
# 1,229       677
#            ...
# 1,995         1
# 1,580         1
# 15,898        1
# 1,195         1
# 1,390         1
# Name: Displacement, Length: 77, dtype: int64

# %%
df1.Displacement = df3.Displacement

# %%
df1.Displacement  = df1.Displacement.str.replace(',','')

# %%
df1.Displacement.astype(float)
# Out:
# 0        1422.0
# 1        1798.0
# 2        1598.0
# 3        1422.0
# 4        1422.0
#           ...
# 15914    1997.0
# 15915    1798.0
# 15916    1997.0
# 15917    1997.0
# 15918    1798.0
# Name: Displacement, Length: 15919, dtype: float64

# %%
df1.Cylinders = df1.Cylinders.str[0].str.strip('\n').astype(float)

# %%
df1.Cylinders.astype(float)
# Out:
# 0        3.0
# 1        4.0
# 2        NaN
# 3        3.0
# 4        3.0
#         ...
# 15914    4.0
# 15915    4.0
# 15916    4.0
# 15917    4.0
# 15918    4.0
# Name: Cylinders, Length: 15919, dtype: float64

# %%
df1.Drive_Chain = df1.Drive_Chain.str[0].str.strip('\n')

# %%
df1.Fuel = df1.Fuel.str[1].str.strip('\n')

# %%
df1.Fuel = df3.Fuel

# %%
df1.Fuel.str[1].str.strip('\n')
# Out:
# 0        i
# 1        a
# 2        i
# 3        i
# 4        i
#         ..
# 15914    i
# 15915    u
# 15916    i
# 15917    i
# 15918    u
# Name: Fuel, Length: 15919, dtype: object

# %%
df1.Fuel.value_counts()
# Out:
# Diesel (Particulate Filter)                                                                                  4315
# Super 95                                                                                                     3338
# Gasoline                                                                                                     3175
# Diesel                                                                                                       2984
# Super 95 / Regular/Benzine 91                                                                                 424
#                                                                                                              ...
# Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super 95 / Super E10 95 / Super Plus E10 98       1
# Super Plus 98 / Super 95 / Super E10 95                                                                         1
# Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98 / Regular/Benzine E10 91       1
# Regular/Benzine 91 / Super 95 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 / Super Plus 98       1
# Super Plus E10 98                                                                                               1
# Name: Fuel, Length: 77, dtype: int64

# %%
df1.Fuel.describe()
# Out:
# count                           15919
# unique                             77
# top       Diesel (Particulate Filter)
# freq                             4315
# Name: Fuel, dtype: object

# %%
df1.Fuel.apply(lambda x : "Diesel" if 'Diesel' in x elif "Gasoline" in x "Gasoline" else "Gasoline")
# Out:
# 0          Diesel
# 1        Gasoline
# 2          Diesel
# 3          Diesel
# 4          Diesel
#            ...
# 15914      Diesel
# 15915    Gasoline
# 15916      Diesel
# 15917      Diesel
# 15918    Gasoline
# Name: Fuel, Length: 15919, dtype: object

# %%
df1.Fuel
# Out:
# 0                          Diesel (Particulate Filter)
# 1                                             Gasoline
# 2                          Diesel (Particulate Filter)
# 3                          Diesel (Particulate Filter)
# 4                          Diesel (Particulate Filter)
#                              ...
# 15914                      Diesel (Particulate Filter)
# 15915    Super 95 / Super Plus 98 (Particulate Filter)
# 15916                                           Diesel
# 15917                                           Diesel
# 15918                                         Super 95
# Name: Fuel, Length: 15919, dtype: object

# %%
df1.Fuel = df3.Fuel

# %%
df3.Fuel = df1.Fuel

# %%
df1.Fuel = df1.Fuel.apply(lambda x : "Diesel" if 'Diesel' in x else x)

# %%
df1.Fuel.value_counts()
# Out:
# Diesel (Particulate Filter)                                                                                  4315
# Super 95                                                                                                     3338
# Gasoline                                                                                                     3175
# Diesel                                                                                                       2984
# Super 95 / Regular/Benzine 91                                                                                 424
#                                                                                                              ...
# Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super 95 / Super E10 95 / Super Plus E10 98       1
# Super Plus 98 / Super 95 / Super E10 95                                                                         1
# Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98 / Regular/Benzine E10 91       1
# Regular/Benzine 91 / Super 95 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 / Super Plus 98       1
# Super Plus E10 98                                                                                               1
# Name: Fuel, Length: 77, dtype: int64

# %%
df1.Fuel.describe()
# Out:
# count                           15919
# unique                             42
# top       Diesel (Particulate Filter)
# freq                             4315
# Name: Fuel, dtype: object

# %%
df1.Fuel = df1.Fuel.apply(lambda x : "Gasoline" if 'Benzine' in x else x)

# %%
df1.Fuel = df1.Fuel.apply(lambda x : "Gasoline" if 'Super' in x else x)

# %%
df1.Fuel = df1.Fuel.apply(lambda x : "LPG" if 'LPG' in x else "Others")

# %%
df1.Fuel = df1.Fuel.apply(lambda x : "Gasoline" if "Benzine" in x else x)

# %%
df1.Fuel
# Out:
# 0                          Diesel (Particulate Filter)
# 1                                             Gasoline
# 2                          Diesel (Particulate Filter)
# 3                          Diesel (Particulate Filter)
# 4                          Diesel (Particulate Filter)
#                              ...
# 15914                      Diesel (Particulate Filter)
# 15915    Super 95 / Super Plus 98 (Particulate Filter)
# 15916                                           Diesel
# 15917                                           Diesel
# 15918                                         Super 95
# Name: Fuel, Length: 15919, dtype: object

# %%
df1.Fuel = df1.Fuel.apply(lambda x : "Diesel" if "Diesel" in x else x )

# %%
df1.Fuel = df1.Fuel.apply(Fuel_type)

# %%
def Fuel_type(x):
    if "Benzine" in x :
        return "Gasoline"
    elif "Gasoline" in x :
        return "Gasoline"
    elif "Super" in x :
        return "Gasoline"
    elif "Diesel" in x :
        return "Diesel"
    elif "LPG" in x :
        return "LPG"
    else :
        return "Others"

# %%
df1.Fuel.value_counts()
# Out:
# Gasoline    8549
# Diesel      7299
# Others        45
# LPG           26
# Name: Fuel, dtype: int64
