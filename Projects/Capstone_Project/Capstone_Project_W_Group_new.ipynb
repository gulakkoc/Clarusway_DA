# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## EDA for Car Price Prediction Model

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_json('scout_car.json', lines=True)

# %%
df.sample(20).T
# Out:
#                                                                            8925   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                                                 1.4 90CV Start
# body_type                                                                 Sedans
# price                                                                       7500
# vat                                                               VAT deductible
# km                                                                     90,700 km
# registration                                                             02/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                [\n12 months\n, \n110 g CO2/km (comb)\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                            [\n, Semi-automatic, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,163 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[4.7 l/100 km (comb)], [5.8 l/100 km (city)],...
# CO2 Emission                                           [\n110 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, F...
# description                    [\nGrazie per essersi interessato ad una delle...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1875   \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                Sportback 1.0 TFSI design NaviVorb/PDC+/SitzHzg
# body_type                                                                 Sedans
# price                                                                      16889
# vat                                                               VAT deductible
# km                                                                      9,916 km
# registration                                                             05/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         60 kW
# Type                                    [, Employee's car, , Regular/Benzine 91]
# Previous Owners                                                            \n1\n
# Next Inspection                            [\n05/2021\n, \n97 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                      [\n70-50708\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                 [\nGletscherweiß Metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BHM\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                [\n, Regular/Benzine 91, \n]
# Consumption                    [[4.2 l/100 km (comb)], [5 l/100 km (city)], [...
# CO2 Emission                                            [\n97 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Sport seat...
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Highlights:, Anschlussgarantie 3 Jahre, m...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            6982   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                              1.4 Turbo S&S Excellence (125 CV)
# body_type                                                                Compact
# price                                                                      11955
# vat                                                                         None
# km                                                                     39,754 km
# registration                                                             03/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         92 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                   [\n, \n, \n117 g CO2/km (comb)\n]
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                       [\n6930JXT\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                         [\n, Red, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                           [\nBlack\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,278 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.1 l/100 km (comb)], [6.3 l/100 km (city)],...
# CO2 Emission                                           [\n117 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Cruise control, Hill Holder, Multi-function s...
# \nEntertainment & Media\n                                            [Bluetooth]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n                  [Isofix, Tire pressure monitoring system]
# description                    [\n, 6930JXT, Oferta de financiación, consulta...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            13160  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                                    1.2TCe EDC automaat INTENSE
# body_type                                                          Station wagon
# price                                                                      14950
# vat                                                               VAT deductible
# km                                                                     53,332 km
# registration                                                             05/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         88 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n05/2020\n, \n120 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                        [\nSX966X\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                  [\nGrijs\n]
# Upholstery                                                           [\nCloth\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,197 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,170 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.4 l/100 km (comb)], [6.8 l/100 km (city)],...
# CO2 Emission                                           [\n120 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                  [CD player, On-board computer, Radio]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nBel 0475-562256 of 0655560682 voor een proe...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                [\nNetherlands\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            245    \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                  Sportback 1.4 TFSI S tronic Navigation Euro 6
# body_type                                                                 Sedans
# price                                                                      17240
# vat                                                                         None
# km                                                                     40,550 km
# registration                                                             06/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         92 kW
# Type                                   [, Used, , Super 95 / Regular/Benzine 91]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                 [\nYes\n, \n, 4.9 l/100 km (comb), \n, 6.2 l/1...
# Warranty                                       [\n, \n, \n112 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                        [\nF51613\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                        [\nBrillantschwarz\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n4\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,395 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                     [\n, Super 95 / Regular/Benzine 91, \n]
# Consumption                    [\n, 4.9 l/100 km (comb), \n, 6.2 l/100 km (ci...
# CO2 Emission                                           [\n112 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Electrical side mirrors, Hi...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Fahrzeugnummer: F51613, 1. Hand, unfallfr...
# Emission Label                                                               NaN
# Gears                                                                    [\n7\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                    [[], [], []]
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            4810   \
# url                            https://www.autoscout24.com//offers/audi-a3-li...
# make_model                                                               Audi A3
# short_description                                        Limousine 1.6 TDI Sport
# body_type                                                                 Sedans
# price                                                                      21480
# vat                                                               VAT deductible
# km                                                                      8,015 km
# registration                                                             07/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n07/2021\n, \n107 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                       [\nAV91033\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                 [\nflorettsilber metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BLG\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2 Emission                                           [\n107 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                            [Alloy wheels, Sport package, Sport seats]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Fahrzeug-Nummer: AV91033,  , Navigationss...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            9561   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                       E 1,4 Alu*Tempomat*Navi*IntelliLink*1.Hd
# body_type                                                                 Sedans
# price                                                                       9490
# vat                                                               VAT deductible
# km                                                                     23,600 km
# registration                                                             01/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n01/2021\n, \n120 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                      [\n30141FS3\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                   [\ngrau\n]
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BCB\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                                      [[5.2 l/100 km (comb)], [], []]
# CO2 Emission                                           [\n120 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                                          [Alloy wheels, Touch screen]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nUnfallfrei, Euro6, Klimaanlage, 8 Airbags, ...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            3846   \
# url                            https://www.autoscout24.com//offers/audi-a3-li...
# make_model                                                               Audi A3
# short_description                          Limousine 1,6 TDI S tronic NAVI XENON
# body_type                                                                 Sedans
# price                                                                      21450
# vat                                                               VAT deductible
# km                                                                     25,778 km
# registration                                                             12/2017
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n12/2020\n, \n109 g CO2/km (comb)\n]
# Inspection new                                             [\nYes\n, \nEuro 6\n]
# Warranty                                                 [\n, \n, \n4 (Green)\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                    [\n2061930731\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                 [\nFlorettsilber Metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n4\n]
# Model Code                                                        [\n0588/BLG\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.7 l/100 km (city)],...
# CO2 Emission                                           [\n109 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                                         [Alloy wheels, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Technik & Sicherheit:, Getriebe 7-Gang - ...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            2857   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                SPB 1.6 TDI S TRONIC AMBITION NAVI+C.L16+PDC!!!
# body_type                                                                 Sedans
# price                                                                      16500
# vat                                                               VAT deductible
# km                                                                     42,000 km
# registration                                                             01/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                 [\n12 months\n, \n99 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                      [\n11502828\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nGrigio scuro\n]
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,355 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                            [\n99 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n      [Bluetooth, CD player, Digital radio, Hands-fr...
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Alarm system, C...
# description                    [\nCERCHI IN LEGA DA 16, SENSORE PARCHEGGIO, F...
# Emission Label                                                               NaN
# Gears                                                                    [\n7\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            4552   \
# url                            https://www.autoscout24.com//offers/audi-a3-nu...
# make_model                                                               Audi A3
# short_description                  NUOVA SPORTBACK Sportback 1,0 L3 85 DSG MY 19
# body_type                                                                 Sedans
# price                                                                      23500
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                             02/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                              [, Pre-registered, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n106 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                       [\n2740706\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                         [\nNero Brillante\n]
# Upholstery                                                           [\nOther\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,200 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[4.6 l/100 km (comb)], [5.5 l/100 km (city)],...
# CO2 Emission                                           [\n106 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Multi-function steering whe...
# \nEntertainment & Media\n             [Bluetooth, On-board computer, Radio, USB]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\nDEK:[2740706], Cod. 58723-N, Siamo concessi...
# Emission Label                                                               NaN
# Gears                                                                    [\n7\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            11911  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                        1,5 Turbo Innovation FLH Navi.,Klimaaut
# body_type                                                                 Sedans
# price                                                                      23490
# vat                                                               VAT deductible
# km                                                                     18,400 km
# registration                                                             08/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        121 kW
# Type                                   [, Used, , Super 95 / Regular/Benzine 91]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                       [\n60 months\n, \n, 6 l/100 km (comb), \n, 7.3...
# Full Service                                   [\n, \n, \n142 g CO2/km (comb)\n]
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# ...
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,278 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.1 l/100 km (comb)], [6.3 l/100 km (city)],...
# CO2 Emission                                           [\n117 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Cruise control, Hill Holder, Multi-function s...
# \nEntertainment & Media\n                                            [Bluetooth]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n                  [Isofix, Tire pressure monitoring system]
# description                    [\n, 6930JXT, Oferta de financiación, consulta...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            12103  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                        2.0 CDTI Innovation Matrix-LED,2xKamera
# body_type                                                          Station wagon
# price                                                                      21550
# vat                                                               VAT deductible
# km                                                                     25,150 km
# registration                                                             06/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        125 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                [\n60 months\n, \n148 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                   [\nInsignia024\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                             [\nQuarz Grau\n]
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,956 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[5.6 l/100 km (comb)], [7.3 l/100 km (city)],...
# CO2 Emission                                           [\n148 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                                [Alloy wheels, Roof rack, Sport seats]
# \nSafety & Security\n          [ABS, Adaptive headlights, Central door lock, ...
# description                    [\nIhre Ansprechpartner für dieses KFZ:,  ,  ,...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            7374   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                        1.6 CDTi 136CV INNOVATION SEDE DI CUNEO
# body_type                                                          Station wagon
# price                                                                      14950
# vat                                                               VAT deductible
# km                                                                     19,000 km
# registration                                                             04/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                           [, Employee's car, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                [\n12 months\n, \n121 g CO2/km (comb)\n]
# Full Service                                          [\n, \n, \nEuro 6d-TEMP\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                           [\n991\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,403 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.6 l/100 km (comb)], [5.5 l/100 km (city)],...
# CO2 Emission                                           [\n121 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n                                     [Bluetooth, Radio]
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Handicappe...
# \nSafety & Security\n          [ABS, Central door lock, Central door lock wit...
# description                    [\n, AUTOVETTURA VISIONABILE PRESSO LA NOSTRA ...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            9402
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                       1.2 Selection Klima/USB/Bluetooth/IsoFix
# body_type                                                                Compact
# price                                                                       8980
# vat                                                                         None
# km                                                                     16,000 km
# registration                                                             07/2017
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         51 kW
# Type                                   [, Used, , Super 95 / Regular/Benzine 91]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                       [\n60 months\n, \n, 5.4 l/100 km (comb), \n, 6...
# Full Service                                   [\n, \n, \n128 g CO2/km (comb)\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                      [\nH4252515\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                         [\n, Red, \n]
# Paint Type                                                                   NaN
# Body Color Original                                               [\nLava Rot\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,229 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                     [\n, Super 95 / Regular/Benzine 91, \n]
# Consumption                    [\n, 5.4 l/100 km (comb), \n, 6.7 l/100 km (ci...
# CO2 Emission                                           [\n128 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Electrical side mirrors, Hi...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nIhre Ansprechpartner für dieses KFZ:,  ,  ,...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n5\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                    [[], [], []]
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %% [markdown]
# ### Things Needs to Be Done
#
# 1. Think about removing url column.
# 2. **Get rid of the column "make_model"**
# 3. **short description
# 4. Body_type : There are 60 nulls values that we have to deal with.
# 5. Be aware of outliers such as min. in price column.
# 6. Vat column : Change it to deductible or not deductible
# 7. For the km column remove the "km" from the rows and change the data type to int or float.
# 8. **Drop the registration column because there is another registratio colum which only contains years.**
# 9. **From prev_owner column remove the part of "previous owner" and change data type to integer. There are 6828 null values.Remove the "Previous owners" column.**
# 10. **Drop the column "kW"**
# 11. Change the "hp" column name to kW.Change the data type.
# 12. Clean the "Type" column.
# 13. **Drop the columns about inspectation.**
# 14. Come back to the Warranty column
# 15. **Drop the Full service column.**
# 16. **Drop the Non_smoking column.**
# 17. **Drop the null column.**
# 18. Clean both make and model columns.
# 19. Come back to the offer number column again.
# 20. Change the First registration column name as Registration year
# 21. **Drop the Body color original**
# 22. Organize Upholstery column
# 23. **Drop the Body column.**
# 24. Check the number of doors
# 25. For the number od seats, clean '\n'
# 26. **Drop the model code number  column**
# 27. Clean the outliers for gearing type column
# 28. For the Cyclinder column clean the outliers.
# 29. **You might drop Weight column(!)**
# 30. Make the small groups for Fuel column.
# 31. We might need the 'Consumption' to be in 3 different column.
# 32. For the CO2 Emission, get rid of the unnecessary string parts and change the column name.
# 33. For the Emission Class column be aware of empty brackets which are null valus and get rid of unnecessary inf.
# 34. Come back to the \nComfort & Convenience\n column.
# 35. Come back to '\nEntertainment & Media\n' column.
# 36. Extras column*
# 37. Safety & Security column*
# 38. **Drop the description column.**
# 39. **Drop the emission column.**
# 40. Gears column*
# 41. **Drop rest of the columns.**

# %%
df.sample(3).T
# Out:
#                                                                            12386  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                           Grand Sport Dynamic,PDC,NSW,Navi,AGR
# body_type                                                                 Sedans
# price                                                                      18990
# vat                                                               VAT deductible
# km                                                                     13,093 km
# registration                                                             01/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        121 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n01/2021\n, \n136 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                         [\n92301\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nOnyx Schwarz\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,490 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[6 l/100 km (comb)], [7.3 l/100 km (city)], [...
# CO2 Emission                                           [\n136 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                          [Alloy wheels, Touch screen]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, - über 50 Jahren Opel - Partner, - Vertra...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            4812   \
# url                            https://www.autoscout24.com//offers/audi-a3-li...
# make_model                                                               Audi A3
# short_description                                        Limousine 1.6 TDI Sport
# body_type                                                                 Sedans
# price                                                                      21480
# vat                                                               VAT deductible
# km                                                                      6,265 km
# registration                                                             06/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n06/2021\n, \n107 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                       [\nAG91124\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                    [\nmonsungrau metallic\n]
# Upholstery                                                    [\nOther, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2 Emission                                           [\n107 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Digital radio, Hands-fr...
# \nExtras\n                                           [Alloy wheels, Sport seats]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Fahrzeug-Nummer: AG91124,  , Navigationss...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            2297
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                SPB 25 TFSI Admired S-Line Edition vari colori
# body_type                                                                 Sedans
# price                                                                      20700
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         70 kW
# Type                                                         [, New, , Gasoline]
# Previous Owners                                                            \n0\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                            [\nbm\n]
# First Registration                                                           NaN
# Body Color                                                       [\n, White, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,165 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[4.6 l/100 km (comb)], [5.8 l/100 km (city)],...
# CO2 Emission                                           [\n104 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, MP3, On-board computer,...
# \nExtras\n                     [Alloy wheels, Sport package, Sport suspension...
# \nSafety & Security\n          [ABS, Alarm system, Central door lock, Driver-...
# description                    [\n, S-line Edition 25 TFSI 5 Marce, Sedili ri...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %%
df1 = df.copy()

# %%
df1.drop('url', axis = 1, inplace = True)
df1.drop('make_model', axis = 1, inplace = True)
df1.drop('short_description', axis = 1, inplace = True)
df1.drop('kW', axis = 1, inplace = True)
df1.drop('registration', axis = 1, inplace = True)
df1.drop('Previous Owners', axis = 1, inplace = True)
df1.drop('Next Inspection', axis = 1, inplace = True)
df1.drop('Inspection new', axis = 1, inplace = True)
df1.drop('Full Service', axis = 1, inplace = True)
df1.drop('null', axis = 1, inplace = True)
df1.drop('Body Color Original', axis = 1, inplace = True)
df1.drop('Body', axis = 1, inplace = True)
df1.drop('Model Code', axis = 1, inplace = True)
df1.drop('Weight', axis = 1, inplace = True)
df1.drop('description', axis = 1, inplace = True)
df1.drop('Emission Label', axis = 1, inplace = True)
df1.drop('Country version', axis = 1, inplace = True)
df1.drop('Electricity consumption', axis = 1, inplace = True)
df1.drop('Last Service Date', axis = 1, inplace = True)
df1.drop('Other Fuel Types', axis = 1, inplace = True)
df1.drop('Availability', axis = 1, inplace = True)
df1.drop('Last Timing Belt Service Date', axis = 1, inplace = True)
df1.drop('Available from', axis = 1, inplace = True)
df1.drop('Non-smoking Vehicle', axis = 1, inplace = True)

# %%
df1.drop('Offer Number', axis = 1, inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   body_type                15859 non-null  object
#  1   price                    15919 non-null  int64
#  2   vat                      11406 non-null  object
#  3   km                       15919 non-null  object
#  4   prev_owner               9091 non-null   object
#  5   hp                       15919 non-null  object
#  6   Type                     15917 non-null  object
#  7   Warranty                 10499 non-null  object
#  8   Make                     15919 non-null  object
#  9   Model                    15919 non-null  object
#  10  First Registration       14322 non-null  object
#  11  Body Color               15322 non-null  object
#  12  Paint Type               10147 non-null  object
#  13  Upholstery               12199 non-null  object
#  14  Nr. of Doors             15707 non-null  object
#  15  Nr. of Seats             14942 non-null  object
#  16  Gearing Type             15919 non-null  object
#  17  Displacement             15423 non-null  object
#  18  Cylinders                10239 non-null  object
#  19  Drive chain              9061 non-null   object
#  20  Fuel                     15919 non-null  object
#  21  Consumption              14013 non-null  object
#  22  CO2 Emission             14111 non-null  object
#  23  Emission Class           12898 non-null  object
#  24
# Comfort & Convenience
#   14999 non-null  object
#  25
# Entertainment & Media
#   14545 non-null  object
#  26
# Extras
#                  12957 non-null  object
#  27
# Safety & Security
#       14937 non-null  object
#  28  Gears                    11207 non-null  object
# dtypes: int64(1), object(28)
# memory usage: 3.5+ MB

# %%
df3 = df.copy()

# %%
df3.km = df3.km.astype('str').replace('- km', np.nan)

# %%
df3.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914          NaN
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918          NaN
# Name: km, Length: 15919, dtype: object

# %%
df3.km  = df3.km.str.strip(" km")

# %%
df3.km = df3.km.str.replace(",", "")

# %%
df3.km
# Out:
# 0        56013
# 1        80000
# 2        83450
# 3        73000
# 4        16200
#          ...
# 15914        -
# 15915     9900
# 15916       15
# 15917       10
# 15918        -
# Name: km, Length: 15919, dtype: object

# %%
df1.km = df3.km

# %%
df1.rename(columns={'hp':'kw'}, inplace = True )

# %%
df1.kw = df3.kw

# %%
df1.kw = df1.kw.str.strip(' kW')

# %%
df1.sample(3).T
# Out:
#                                                                        631    \
# body_type                                                            Compact
# price                                                                  12700
# vat                                                                     None
# km                                                                     36621
# prev_owner                                                  1 previous owner
# kw                                                                        70
# Type                                          [, Used, , Regular/Benzine 91]
# Warranty                                                [\n, \n, \nEuro 6\n]
# Make                                                                \nAudi\n
# Model                                                           [\n, A1, \n]
# First Registration                                            [\n, 2016, \n]
# Body Color                                                    [\n, Blue, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                    [\n999 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                      [\nfront\n]
# Fuel                                            [\n, Regular/Benzine 91, \n]
# Consumption                [[4.4 l/100 km (comb)], [5.2 l/100 km (city)],...
# CO2 Emission                                       [\n104 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Electrical side mirrors, Le...
# \nEntertainment & Media\n         [CD player, MP3, On-board computer, Radio]
# \nExtras\n                 [Alloy wheels, Catalytic Converter, Sport susp...
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                    NaN
#
#                                                                        4033   \
# body_type                                                             Sedans
# price                                                                  17990
# vat                                                           VAT deductible
# km                                                                     79500
# prev_owner                                                  1 previous owner
# kw                                                                        81
# Type                                 [, Used, , Diesel (Particulate Filter)]
# Warranty                                                [\n, \n, \nEuro 6\n]
# Make                                                                \nAudi\n
# Model                                                           [\n, A3, \n]
# First Registration                                            [\n, 2017, \n]
# Body Color                                                     [\n, Red, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n4\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# Consumption                [[3.9 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2 Emission                                       [\n106 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Hands-free equipment, On-board computer, Radi...
# \nExtras\n                                       [Alloy wheels, Sport seats]
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                [\n6\n]
#
#                                                                        15289
# body_type                                                               None
# price                                                                  28140
# vat                                                                     None
# km                                                                        10
# prev_owner                                                              None
# kw                                                                        96
# Type                                                      [, Used, , Diesel]
# Warranty                                                                 NaN
# Make                                                             \nRenault\n
# Model                                                       [\n, Espace, \n]
# First Registration                                                       NaN
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                               NaN
# Upholstery                                                               NaN
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                             NaN
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                              NaN
# Fuel                                                        [\n, Diesel, \n]
# Consumption                [[4.4 l/100 km (comb)], [5.1 l/100 km (city)],...
# CO2 Emission                                       [\n116 g CO2/km (comb)\n]
# Emission Class                                                           NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nExtras\n                                                               NaN
# \nSafety & Security\n                                                    NaN
# Gears                                                                [\n6\n]

# %%
df1.kw = df1.kw.replace(0,np.nan)

# %%
df1.kw = df1.kw.replace('-', np.nan)

# %%
df1.kw = df1.kw.astype(float)

# %%
df1.kW
# Out:
# 0         66.0
# 1        141.0
# 2         85.0
# 3         66.0
# 4         66.0
#          ...
# 15914    147.0
# 15915    165.0
# 15916    146.0
# 15917    147.0
# 15918    165.0
# Name: kW, Length: 15919, dtype: float64

# %%
df1.prev_owner = df1.prev_owner.str.strip(' previous owner')

# %%
df1.prev_owner.value_counts()
# Out:
# 1    8294
# 2     778
# 3      17
# 4       2
# Name: prev_owner, dtype: int64

# %%
df1.prev_owner = df1.prev_owner.astype(float)

# %%
df1.prev_owner
# Out:
# 0        2.0
# 1        NaN
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 15914    NaN
# 15915    1.0
# 15916    1.0
# 15917    NaN
# 15918    1.0
# Name: prev_owner, Length: 15919, dtype: float64

# %% [markdown]
# ### Things Needs to Be Done
#
# 1. Think about removing url column.
# 2. **Get rid of the column "make_model"**
# 3. **short description
# 4. Body_type : There are 60 nulls values that we have to deal with.
# 5. Be aware of outliers such as min. in price column.
# 6. Vat column : Change it to deductible or not deductible
# 7. For the km column remove the "km" from the rows and change the data type to int or float.
# 8. **Drop the registration column because there is another registratio colum which only contains years.**
# 9. **From prev_owner column remove the part of "previous owner" and change data type to integer. There are 6828 null values.Remove the "Previous owners" column.**
# 10. **Drop the column "kW"**
# 11. Change the "hp" column name to kW.Change the data type.
# 12. Clean the "Type" column.
# 13. **Drop the columns about inspectation.**
# 14. Come back to the Warranty column
# 15. **Drop the Full service column.**
# 16. **Drop the Non_smoking column.**
# 17. **Drop the null column.**
# 18. Clean both make and model columns.
# 19. Come back to the offer number column again.
# 20. Change the First registration column name as Registration year
# 21. **Drop the Body color original**
# 22. Organize Upholstery column
# 23. **Drop the Body column.**
# 24. Check the number of doors
# 25. For the number od seats, clean '\n'
# 26. **Drop the model code number  column**
# 27. Clean the outliers for gearing type column
# 28. For the Cyclinder column clean the outliers.
# 29. **You might drop Weight column(!)**
# 30. Make the small groups for Fuel column.
# 31. We might need the 'Consumption' to be in 3 different column.
# 32. For the CO2 Emission, get rid of the unnecessary string parts and change the column name.
# 33. For the Emission Class column be aware of empty brackets which are null valus and get rid of unnecessary inf.
# 34. Come back to the \nComfort & Convenience\n column.
# 35. Come back to '\nEntertainment & Media\n' column.
# 36. Extras column*
# 37. Safety & Security column*
# 38. **Drop the description column.**
# 39. **Drop the emission column.**
# 40. Gears column*
# 41. **Drop rest of the columns.**

# %%
df2 = df1.copy()

# %%
df2.Make = df2.Make.str.strip('\n')

# %%
df1.Make = df2.Make

# %%
df1.Make
# Out:
# 0           Audi
# 1           Audi
# 2           Audi
# 3           Audi
# 4           Audi
#           ...
# 15914    Renault
# 15915    Renault
# 15916    Renault
# 15917    Renault
# 15918    Renault
# Name: Make, Length: 15919, dtype: object

# %%
df3.Model
# Out:
# 0            [\n, A1, \n]
# 1            [\n, A1, \n]
# 2            [\n, A1, \n]
# 3            [\n, A1, \n]
# 4            [\n, A1, \n]
#                ...
# 15914    [\n, Espace, \n]
# 15915    [\n, Espace, \n]
# 15916    [\n, Espace, \n]
# 15917    [\n, Espace, \n]
# 15918    [\n, Espace, \n]
# Name: Model, Length: 15919, dtype: object

# %%
df3.Model=df3.Model.str[1].str.strip('\n')

# %%
df3.Model
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: Model, Length: 15919, dtype: object

# %%
df1.Model = df3.Model

# %%
df1.sample(3).T
# Out:
#                                                                        839    \
# body_type                                                             Sedans
# price                                                                  13950
# vat                                                         Price negotiable
# km                                                                     29275
# prev_owner                                                               1.0
# kw                                                                      70.0
# Type                                                    [, Used, , Gasoline]
# Warranty                                                                 NaN
# Make                                                                    Audi
# Model                                                                     A1
# First Registration                                            [\n, 2016, \n]
# Body Color                                                   [\n, Brown, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                               NaN
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n4\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                    [\n999 cc\n]
# Cylinders                                                            [\n3\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                                      [\n, Gasoline, \n]
# Consumption                [[4.2 l/100 km (comb)], [5 l/100 km (city)], [...
# CO2 Emission                                        [\n97 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                                       [Alloy wheels, Sport seats]
# \nSafety & Security\n      [ABS, Alarm system, Central door lock, Central...
# Gears                                                                [\n5\n]
#
#                                                                        5770   \
# body_type                                                      Station wagon
# price                                                                  15989
# vat                                                           VAT deductible
# km                                                                     40600
# prev_owner                                                               1.0
# kw                                                                     110.0
# Type                               [, Used, , Super 95 / Regular/Benzine 91]
# Warranty                   [\n60 months\n, \n, 5.1 l/100 km (comb), \n, 6...
# Make                                                                    Opel
# Model                                                                  Astra
# First Registration                                            [\n, 2016, \n]
# Body Color                                                   [\n, White, \n]
# Paint Type                                                               NaN
# Upholstery                                                       [\nCloth\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,399 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                              NaN
# Fuel                                 [\n, Super 95 / Regular/Benzine 91, \n]
# Consumption                [\n, 5.1 l/100 km (comb), \n, 6.3 l/100 km (ci...
# CO2 Emission                                       [\n121 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n  [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                         [Alloy wheels, Roof rack]
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                    NaN
#
#                                                                        10416
# body_type                                                            Compact
# price                                                                  11169
# vat                                                           VAT deductible
# km                                                                         5
# prev_owner                                                               NaN
# kw                                                                      51.0
# Type                                                     [, New, , Gasoline]
# Warranty                                                       \n24 months\n
# Make                                                                    Opel
# Model                                                                  Corsa
# First Registration                                                       NaN
# Body Color                                                   [\n, Black, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n3\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,229 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                              NaN
# Fuel                                                      [\n, Gasoline, \n]
# Consumption                                  [[5.6 l/100 km (comb)], [], []]
# CO2 Emission                                       [\n129 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n                     [Bluetooth, On-board computer]
# \nExtras\n                                       [Alloy wheels, Sport seats]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# Gears                                                                [\n5\n]

# %%
df4 = df.copy()

# %%
df3.Type = df1.Type.str[1]

# %%
df1.Type = df3.Type

# %%
df3.Type.value_counts()
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: Type, dtype: int64

# %%
df1.drop('Warranty', axis = 1, inplace = True)

# %%
df1.rename(columns={'Type':'Condition'}, inplace = True)

# %%
df1.rename(columns={'body_type':'Body_Type'}, inplace = True)
df1.rename(columns={'price':'Price'}, inplace = True)
df1.rename(columns={'vat':'Vat'}, inplace = True)
df1.rename(columns={'prev_owner':'Previous_Owner'}, inplace = True)
df1.rename(columns={'First Registration':'Registration_Year'}, inplace = True)
df1.rename(columns={'Body Color':'Body_Color'}, inplace = True)
df1.rename(columns={'Paint Type':'Paint_Type'}, inplace = True)
df1.rename(columns={'Nr. of Doors':'Nr_of_Doors'}, inplace = True)
df1.rename(columns={'Nr. of Seats':'Nr_of_Seats'}, inplace = True)
df1.rename(columns={'Gearing Type':'Gearing_Type'}, inplace = True)
df1.rename(columns={'CO2 Emission':'CO2_Emission'}, inplace = True)
df1.rename(columns={'Emission Class':'Emission_Class'}, inplace = True)
df1.rename(columns={'\nComfort & Convenience\n':'Comfort_Convenience'}, inplace = True)
df1.rename(columns={'\nEntertainment & Media\n':'Entertainment_Media'}, inplace = True)
df1.rename(columns={'\nExtras\n':'Extras'}, inplace = True)
df1.rename(columns={'\nSafety & Security\n':'Safety & Security'}, inplace = True)
df1.rename(columns={'kw':'kW'}, inplace = True)

# %%
df1.rename(columns={'Safety & Security':'Safety_Security'}, inplace = True)

# %%
df1.rename(columns={'Drive chain':'Drive_Chain'}, inplace = True)

# %%
df1.rename(columns={'km':'Km'}, inplace = True)

# %%
df1.sample(3).T
# Out:
#                                                                   8831  \
# Body_Type                                                      Compact
# Price                                                            13890
# Vat                                                     VAT deductible
# Km                                                               10115
# Previous_Owner                                                     1.0
# kW                                                                66.0
# Condition                                               Employee's car
# Make                                                              Opel
# Model                                                            Corsa
# Registration_Year                                       [\n, 2018, \n]
# Body_Color                                            [\n, Silver, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,398 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                [\nfront\n]
# Fuel                                            [\n, Super E10 95, \n]
# Consumption          [[6.6 l/100 km (comb)], [8.2 l/100 km (city)],...
# CO2_Emission                                 [\n150 g CO2/km (comb)\n]
# Emission_Class                                      [\nEuro 6d-TEMP\n]
# Comfort_Convenience  [Air conditioning, Cruise control, Electrical ...
# Entertainment_Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras                                    [Alloy wheels, Touch screen]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n6\n]
#
#                                                                   337   \
# Body_Type                                                      Compact
# Price                                                            14990
# Vat                                                               None
# Km                                                               49351
# Previous_Owner                                                     2.0
# kW                                                                66.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A1
# Registration_Year                                       [\n, 2016, \n]
# Body_Color                                             [\n, Black, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                           [\nCloth, Grey\n]
# Nr_of_Doors                                                    [\n4\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,422 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[4 l/100 km (comb)], [4.4 l/100 km (city)], [...
# CO2_Emission                                 [\n104 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                      [Alloy wheels, Sport seats, Voice Control]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN
#
#                                                                   3455
# Body_Type                                                       Sedans
# Price                                                            18000
# Vat                                                               None
# Km                                                               49000
# Previous_Owner                                                     NaN
# kW                                                                81.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A3
# Registration_Year                                       [\n, 2016, \n]
# Body_Color                                              [\n, Grey, \n]
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                  [\n, Semi-automatic, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                        NaN
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2_Emission                                  [\n99 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                       [Alloy wheels, Sport seats, Winter tyres]
# Safety_Security      [ABS, Alarm system, Central door lock, Central...
# Gears                                                          [\n7\n]

# %%
df1.First_Registration = df3['First Registration'].str[1]

# %%
df1.sample(3).T
# Out:
#                                                                  14368  \
# Body_Type                                                       Sedans
# Price                                                            25990
# Vat                                                               None
# Km                                                                7900
# Previous_Owner                                                     1.0
# kW                                                               162.0
# Condition                                                         Used
# Make                                                           Renault
# Model                                                             Clio
# Registration_Year                                       [\n, 2018, \n]
# Body_Color                                             [\n, Black, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                   [\nFull leather, Black\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,618 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                                                [\n, Gasoline, \n]
# Consumption          [[5.9 l/100 km (comb)], [7.6 l/100 km (city)],...
# CO2_Emission                                 [\n135 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras               [Alloy wheels, Sport package, Sport seats, Spo...
# Safety_Security      [ABS, Central door lock, Central door lock wit...
# Gears                                                          [\n6\n]
#
#                                                                  13216  \
# Body_Type                                                       Sedans
# Price                                                            14900
# Vat                                                               None
# Km                                                               36500
# Previous_Owner                                                     1.0
# kW                                                                88.0
# Condition                                                         Used
# Make                                                           Renault
# Model                                                             Clio
# Registration_Year                                       [\n, 2017, \n]
# Body_Color                                              [\n, Blue, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,197 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                        NaN
# Fuel                                                [\n, Gasoline, \n]
# Consumption          [[5.4 l/100 km (comb)], [6.8 l/100 km (city)],...
# CO2_Emission                                 [\n120 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment_Media                              [Bluetooth, MP3, USB]
# Extras                                                  [Alloy wheels]
# Safety_Security      [ABS, Central door lock with remote control, D...
# Gears                                                          [\n6\n]
#
#                                                                  15350
# Body_Type                                                     Off-Road
# Price                                                            27850
# Vat                                                               None
# Km                                                               32400
# Previous_Owner                                                     NaN
# kW                                                               118.0
# Condition                                                         Used
# Make                                                           Renault
# Model                                                           Espace
# Registration_Year                                       [\n, 2018, \n]
# Body_Color                                             [\n, Black, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                          [\nPart leather\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,600 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                                                  [\n, Diesel, \n]
# Consumption                                                        NaN
# CO2_Emission                                                       NaN
# Emission_Class                                                     NaN
# Comfort_Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment_Media                                [On-board computer]
# Extras                                                  [Alloy wheels]
# Safety_Security      [ABS, Central door lock, Driver-side airbag, E...
# Gears                                                          [\n5\n]

# %% [markdown]
# 1. Create age column.

# %% [markdown]
# ### Things Needs to Be Done
#
# 1. Think about removing url column.
# 2. **Get rid of the column "make_model"**
# 3. **short description
# 4. Body_type : There are 60 nulls values that we have to deal with.
# 5. Be aware of outliers such as min. in price column.
# 6. Vat column : Change it to deductible or not deductible
# 7. For the km column remove the "km" from the rows and change the data type to int or float.
# 8. **Drop the registration column because there is another registratio colum which only contains years.**
# 9. **From prev_owner column remove the part of "previous owner" and change data type to integer. There are 6828 null values.Remove the "Previous owners" column.**
# 10. **Drop the column "kW"**
# 11. Change the "hp" column name to kW.Change the data type.
# 12. Clean the "Type" column.
# 13. **Drop the columns about inspectation.**
# 14. Come back to the Warranty column
# 15. **Drop the Full service column.**
# 16. **Drop the Non_smoking column.**
# 17. **Drop the null column.**
# 18. Clean both make and model columns.
# 19. Come back to the offer number column again.
# 20. Change the First registration column name as Registration year
# 21. **Drop the Body color original**
# 22. Organize Upholstery column
# 23. **Drop the Body column.**
# 24. Check the number of doors
# 25. For the number od seats, clean '\n'
# 26. **Drop the model code number  column**
# 27. Clean the outliers for gearing type column
# 28. For the Cyclinder column clean the outliers.
# 29. **You might drop Weight column(!)**
# 30. Make the small groups for Fuel column.
# 31. We might need the 'Consumption' to be in 3 different column.
# 32. For the CO2 Emission, get rid of the unnecessary string parts and change the column name.
# 33. For the Emission Class column be aware of empty brackets which are null valus and get rid of unnecessary inf.
# 34. Come back to the \nComfort & Convenience\n column.
# 35. Come back to '\nEntertainment & Media\n' column.
# 36. Extras column*
# 37. Safety & Security column*
# 38. **Drop the description column.**
# 39. **Drop the emission column.**
# 40. Gears column*
# 41. **Drop rest of the columns.**

# %%
df1.Body_Color = df1.Body_Color.str[1]

# %%
df1["Upholstery"] = df1["Upholstery"].apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Upholstery
# Out:
# 0               \nCloth, Black\n
# 1                \nCloth, Grey\n
# 2               \nCloth, Black\n
# 3                            NaN
# 4               \nCloth, Black\n
#                   ...
# 15914                        NaN
# 15915                  \nCloth\n
# 15916    \nFull leather, Black\n
# 15917           \nPart leather\n
# 15918    \nFull leather, Brown\n
# Name: Upholstery, Length: 15919, dtype: object

# %%
df1.Upholstery = df1.Upholstery.str.strip("\n")

# %%
df1.Upholstery.value_counts()
# Out:
# Cloth, Black           5821
# Part leather, Black    1121
# Cloth                  1005
# Cloth, Grey             891
# Cloth, Other            639
# Full leather, Black     575
# Black                   491
# Grey                    273
# Other, Other            182
# Part leather            140
# Full leather            139
# Full leather, Brown     116
# Part leather, Grey      116
# Other, Black            110
# Full leather, Other      72
# Full leather, Grey       67
# Part leather, Other      65
# Other                    56
# Part leather, Brown      50
# alcantara, Black         47
# Full leather, Beige      36
# Velour, Black            36
# Cloth, Brown             28
# Velour                   16
# Other, Grey              15
# Cloth, Beige             13
# Brown                    12
# Cloth, Blue              12
# Velour, Grey              8
# Cloth, White              8
# alcantara, Grey           6
# Cloth, Red                5
# Other, Yellow             4
# Part leather, Red         3
# Beige                     3
# White                     2
# Blue                      2
# Full leather, Blue        2
# alcantara, Other          2
# Part leather, White       2
# Part leather, Beige       2
# alcantara                 2
# Full leather, White       1
# Cloth, Orange             1
# Full leather, Red         1
# Other, Brown              1
# Name: Upholstery, dtype: int64

# %%
df1.Paint_Type = df1["Paint_Type"].apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Paint_Type = df1.Paint_Type.str.strip('\n')

# %%
df1.Paint_Type
# Out:
# 0        Metallic
# 1             NaN
# 2        Metallic
# 3        Metallic
# 4        Metallic
#            ...
# 15914    Metallic
# 15915    Metallic
# 15916         NaN
# 15917         NaN
# 15918    Metallic
# Name: Paint_Type, Length: 15919, dtype: object

# %%
df1.Nr_of_Doors = df1.Nr_of_Doors.apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Nr_of_Doors = df1.Nr_of_Doors.str.strip('\n')

# %%
df1.Nr_of_Seats = df1.Nr_of_Seats.apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Nr_of_Seats = df1.Nr_of_Seats.str.strip('\n')

# %%
df1.sample(3).T
# Out:
#                                                                  826    \
# Body_Type                                                      Compact
# Price                                                            13989
# Vat                                                               None
# Km                                                               56200
# Previous_Owner                                                     2.0
# kW                                                                85.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A1
# Registration_Year                                       [\n, 2016, \n]
# Body_Color                                                         Red
# Paint_Type                                                    Metallic
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          4
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                [\nfront\n]
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption                                                        NaN
# CO2_Emission                                                       NaN
# Emission_Class                                            [[], [], []]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, CD player, MP3, On-board computer,...
# Extras                   [Alloy wheels, Sport seats, Sport suspension]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN
#
#                                                                  4626   \
# Body_Type                                                       Sedans
# Price                                                            22650
# Vat                                                     VAT deductible
# Km                                                                7727
# Previous_Owner                                                     NaN
# kW                                                                85.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A3
# Registration_Year                                       [\n, 2018, \n]
# Body_Color                                                       Black
# Paint_Type                                                    Metallic
# Upholstery                                                         NaN
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                        NaN
# Fuel                                                  [\n, Diesel, \n]
# Consumption          [[4 l/100 km (comb)], [4.2 l/100 km (city)], [...
# CO2_Emission                                 [\n103 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment_Media                         [On-board computer, Radio]
# Extras                                [Alloy wheels, Sport suspension]
# Safety_Security      [ABS, Driver-side airbag, Electronic stability...
# Gears                                                          [\n7\n]
#
#                                                                  10479
# Body_Type                                                Station wagon
# Price                                                            16900
# Vat                                                     VAT deductible
# Km                                                               47000
# Previous_Owner                                                     1.0
# kW                                                               100.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                         Insignia
# Registration_Year                                       [\n, 2017, \n]
# Body_Color                                                       Black
# Paint_Type                                                    Metallic
# Upholstery                                         Part leather, Black
# Nr_of_Doors                                                          4
# Nr_of_Seats                                                          5
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[5.1 l/100 km (comb)], [6.5 l/100 km (city)],...
# CO2_Emission                                 [\n118 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                         [Alloy wheels, Roof rack, Touch screen]
# Safety_Security      [ABS, Alarm system, Central door lock, Daytime...
# Gears                                                              NaN

# %%
df1.Gearing_Type = df1.Gearing_Type.apply(lambda item: item[1] if type(item) == list else item)
df1.Gearing_Type = df1.Gearing_Type.str.strip('\n')

# %%
df1.Gearing_Type = df1.Gearing_Type.str.strip('\n')

# %%
df1.Gearing_Type
# Out:
# 0        Automatic
# 1        Automatic
# 2        Automatic
# 3        Automatic
# 4        Automatic
#            ...
# 15914    Automatic
# 15915    Automatic
# 15916    Automatic
# 15917    Automatic
# 15918    Automatic
# Name: Gearing_Type, Length: 15919, dtype: object

# %%
df1.Displacement = df3.Displacement

# %%
df1.Displacement = df1.Displacement.apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Displacement = df1.Displacement.str.strip('\n').str.strip(' cc\n')

# %%
df1.Displacement  = df1.Displacement.str.replace(',','')

# %%
df1.Displacement=df1.Displacement.astype(float)

# %%
df1.Cylinders = df1.Cylinders.str[0].str.strip('\n').astype(float)

# %%
df1.Drive_Chain = df1.Drive_Chain.str[0].str.strip('\n')

# %%
df1.Fuel = df1.Fuel.str[1].str.strip('\n')

# %%
df1.Fuel
# Out:
# 0                          Diesel (Particulate Filter)
# 1                                             Gasoline
# 2                          Diesel (Particulate Filter)
# 3                          Diesel (Particulate Filter)
# 4                          Diesel (Particulate Filter)
#                              ...
# 15914                      Diesel (Particulate Filter)
# 15915    Super 95 / Super Plus 98 (Particulate Filter)
# 15916                                           Diesel
# 15917                                           Diesel
# 15918                                         Super 95
# Name: Fuel, Length: 15919, dtype: object

# %%
def Fuel_type(x):
    if "Benzine" in x :
        return "Gasoline"
    elif "Gasoline" in x :
        return "Gasoline"
    elif "Super" in x :
        return "Gasoline"
    elif "Diesel" in x :
        return "Diesel"
    elif "LPG" in x :
        return "LPG"
    else :
        return "Others"

# %%
df1.Fuel = df1.Fuel.apply(Fuel_type)

# %%
df1.Fuel.value_counts()
# Out:
# Gasoline    8549
# Diesel      7299
# Others        45
# LPG           26
# Name: Fuel, dtype: int64

# %%
df1['Combined'] = df1.Consumption.str[0].str[0]

# %%
df1.Combined = df1.Consumption.str[0].str[0].str.split().str[0]

# %%
df1.Combined_Cons = df1.Combined

# %%
df1.Combined_Cons
# Out:
# 0        3.8
# 1        5.6
# 2        3.8
# 3        3.8
# 4        4.1
#         ...
# 15914    5.3
# 15915    NaN
# 15916    5.3
# 15917    5.3
# 15918    6.8
# Name: Combined_Cons, Length: 15919, dtype: object

# %%
df1.Combined_Cons=df1.Combined.astype(float)

# %%
df1.Combined_Cons
# Out:
# 0        3.8
# 1        5.6
# 2        3.8
# 3        3.8
# 4        4.1
#         ...
# 15914    5.3
# 15915    NaN
# 15916    5.3
# 15917    5.3
# 15918    6.8
# Name: Combined_Cons, Length: 15919, dtype: float64

# %%
df1.City_Cons = df1.Consumption.str[1].str[0].str.split().str[0].astype(float)

# %%
df1.City_Cons
# Out:
# 0        4.3
# 1        7.1
# 2        4.4
# 3        4.3
# 4        4.6
#         ...
# 15914    6.2
# 15915    7.0
# 15916    6.2
# 15917    6.2
# 15918    8.7
# Name: Consumption, Length: 15919, dtype: float64

# %%
df1.Highway_Cons = df1.Consumption.str[2].str[0].str.split().str[0].astype(float)

# %%
df1.Highway_Cons
# Out:
# 0        3.5
# 1        4.7
# 2        3.4
# 3        3.5
# 4        3.8
#         ...
# 15914    4.7
# 15915    NaN
# 15916    4.7
# 15917    4.7
# 15918    5.7
# Name: Consumption, Length: 15919, dtype: float64

# %%
df1.sample(3).T
# Out:
#                                                                   8025  \
# Body_Type                                                       Sedans
# Price                                                            16464
# Vat                                                     VAT deductible
# Km                                                                   -
# Previous_Owner                                                     NaN
# kW                                                                78.0
# Condition                                                          New
# Make                                                              Opel
# Model                                                            Astra
# Registration_Year                                                  NaN
# Body_Color                                                       White
# Paint_Type                                                   Uni/basic
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                                    Manual
# Displacement                                                     999.0
# Cylinders                                                          3.0
# Drive_Chain                                                        NaN
# Fuel                                                          Gasoline
# Consumption                                                        NaN
# CO2_Emission                                              [[], [], []]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Cruise control, Electrical ...
# Entertainment_Media                [Bluetooth, MP3, On-board computer]
# Extras                                                  [Alloy wheels]
# Safety_Security      [ABS, Central door lock, Driver-side airbag, E...
# Gears                                                          [\n5\n]
# Combined_Cons                                                      NaN
#
#                                                                   5427  \
# Body_Type                                                       Sedans
# Price                                                            24200
# Vat                                                     VAT deductible
# Km                                                                  10
# Previous_Owner                                                     NaN
# kW                                                                85.0
# Condition                                               Pre-registered
# Make                                                              Audi
# Model                                                               A3
# Registration_Year                                       [\n, 2019, \n]
# Body_Color                                                       Black
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                                    Manual
# Displacement                                                    1598.0
# Cylinders                                                          4.0
# Drive_Chain                                                      front
# Fuel                                                            Diesel
# Consumption          [[4 l/100 km (comb)], [4.5 l/100 km (city)], [...
# CO2_Emission                                 [\n106 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Multi-function steering whe...
# Entertainment_Media              [Bluetooth, On-board computer, Radio]
# Extras                                                  [Alloy wheels]
# Safety_Security      [ABS, Central door lock, Driver-side airbag, E...
# Gears                                                          [\n6\n]
# Combined_Cons                                                      4.0
#
#                                                                   4217
# Body_Type                                                Station wagon
# Price                                                            18890
# Vat                                                     VAT deductible
# Km                                                               24018
# Previous_Owner                                                     1.0
# kW                                                                85.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A3
# Registration_Year                                       [\n, 2017, \n]
# Body_Color                                                        Grey
# Paint_Type                                                    Metallic
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                          4
# Nr_of_Seats                                                          5
# Gearing_Type                                                    Manual
# Displacement                                                    1598.0
# Cylinders                                                          4.0
# Drive_Chain                                                      front
# Fuel                                                            Diesel
# Consumption          [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2_Emission                                 [\n108 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras               [Alloy wheels, Sport package, Sport seats, Spo...
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n6\n]
# Combined_Cons                                                      4.1

# %%
df1.CO2_Emission = df1.CO2_Emission.str[0]

# %%
df1.CO2_Emission
# Out:
# 0         \n99 g CO2/km (comb)\n
# 1        \n129 g CO2/km (comb)\n
# 2         \n99 g CO2/km (comb)\n
# 3         \n99 g CO2/km (comb)\n
# 4        \n109 g CO2/km (comb)\n
#                   ...
# 15914    \n139 g CO2/km (comb)\n
# 15915    \n168 g CO2/km (comb)\n
# 15916    \n139 g CO2/km (comb)\n
# 15917    \n139 g CO2/km (comb)\n
# 15918    \n153 g CO2/km (comb)\n
# Name: CO2_Emission, Length: 15919, dtype: object

# %%
df1.CO2_Emission = df1.CO2_Emission.str.strip(' g CO2/km (comb)\n').str.replace(',',"")

# %%
df1.CO2_Emission
# Out:
# 0         99
# 1        129
# 2         99
# 3         99
# 4        109
#         ...
# 15914    139
# 15915    168
# 15916    139
# 15917    139
# 15918    153
# Name: CO2_Emission, Length: 15919, dtype: object

# %%
df1.CO2_Emission = df1.CO2_Emission.astype(float)

# %%
df1.Emission_Class = df1.Emission_Class.str[0].str.strip('\n')

# %%
df1.Emission_Class.value_counts()
# Out:
# Euro 6          10139
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: Emission_Class, dtype: int64
