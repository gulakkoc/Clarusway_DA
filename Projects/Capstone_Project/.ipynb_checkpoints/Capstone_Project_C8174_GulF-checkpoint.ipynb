# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## EDA for Car Price Prediction Model

# %% [markdown]
# >In this project we are going to be cleaning and analyzing a file for a car price prediction model.

# %% [markdown]
# - Before start analyzing first let's import the libraries we might use for further steps.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# - - -

# %% [markdown]
# <img src="readme.png" style="height:1000px">

# %% [markdown]
# <br>

# %% [markdown]
# - Right after importing the libraries, I am going to read the json file that I am going to be working on.

# %% [markdown]
# <br>

# %%
df = pd.read_json("scout_car.json", lines=True)

# %% [markdown]
# <br>

# %% [markdown]
# - To get an idea of what the data looks like, let's have a look at that by getting some random samples.
# - I am going to get the tranpose of it to see all the columns.

# %% [markdown]
# <br>

# %%
df.sample(20).T
# Out:
#                                                                            6989   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                              1.4 Turbo S&S Excellence (125 CV)
# body_type                                                                Compact
# price                                                                      11955
# vat                                                                         None
# km                                                                     39,754 km
# registration                                                             03/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         92 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                   [\n, \n, \n117 g CO2/km (comb)\n]
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                       [\n6930JXT\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                         [\n, Red, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                           [\nBlack\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,278 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.1 l/100 km (comb)], [6.3 l/100 km (city)],...
# CO2 Emission                                           [\n117 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Cruise control, Hill Holder, Multi-function s...
# \nEntertainment & Media\n                                            [Bluetooth]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n                  [Isofix, Tire pressure monitoring system]
# description                    [\n, 6930JXT, Oferta de financiación, consulta...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            14272  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                             1.2 Klima keycard T.omat BTH Radio
# body_type                                                                Compact
# price                                                                       9998
# vat                                                               VAT deductible
# km                                                                          - km
# registration                                                             08/2018
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         55 kW
# Type                                              [, Pre-registered, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n127 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                          [\n1603\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                        [\nArktis-Weiß 369\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,149 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.6 l/100 km (comb)], [7.2 l/100 km (city)],...
# CO2 Emission                                           [\n127 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                                                       [Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\nDie Werks-Garantie beginnt ab eingetragenem...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                         \nin 3 days from ordering\n
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            7514   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                                  1.6 CDTi 81kW (110CV) Dynamic
# body_type                                                                  Other
# price                                                                      14300
# vat                                                                         None
# km                                                                     17,100 km
# registration                                                             01/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                 [\n24 months\n, \n97 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                             [\n616_350_1201_1137\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                               [\nPlateado\n]
# Upholstery                                                                   NaN
# Body                                                             [\n, Other, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,360 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[3.7 l/100 km (comb)], [4.2 l/100 km (city)],...
# CO2 Emission                                            [\n97 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n                                                    NaN
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n                                                        NaN
# description                                                                   []
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            15514  \
# url                            https://www.autoscout24.com//offers/renault-es...
# make_model                                                        Renault Espace
# short_description                           Intens TCE225 EDC mit Cruising-Paket
# body_type                                                                    Van
# price                                                                      31850
# vat                                                               VAT deductible
# km                                                                     22,200 km
# registration                                                             03/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        165 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n153 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                           [\n, Espace, \n]
# Offer Number                                        [\nEspace V Intens TCE225\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                          [\nTitanium-grau\n]
# Upholstery                                                    [\nPart leather\n]
# Body                                                               [\n, Van, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n7\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,798 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
# CO2 Emission                                           [\n153 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Digital radio, Hands-free equipmen...
# \nExtras\n                           [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Adaptive headli...
# description                    [\n, Sonderausstattung:, 3.Sitzreihe mit Einze...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            5123   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                     Sportback 35 TFSI 150 S-tronic Nav PDC SHZ
# body_type                                                                 Sedans
# price                                                                      26488
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                           [, New, , Regular/Benzine 91 (Particulate Filt...
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n117 g CO2/km (comb)\n]
# Warranty                                              [\n, \n, \nEuro 6d-TEMP\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                       [\nGW-V430\n]
# First Registration                                                           NaN
# Body Color                                                        [\n, Blue, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                       [\nArablau Metallic\n]
# Upholstery                                                           [\nCloth\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BLL\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,498 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,345 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                           [\n, Regular/Benzine 91 (Particulate Filter), \n]
# Consumption                    [[5.2 l/100 km (comb)], [6.4 l/100 km (city)],...
# CO2 Emission                                           [\n117 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                           [Alloy wheels, Roof rack, Sport suspension]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Aktionspreis,  auf limitierte Stückzahl -...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                             [\nEuropean Union\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                      \n31/08/19\n
#
#                                                                            11752  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                        B 5t 1.5 DiTurbo Selection/Navi/PDC/17"
# body_type                                                                 Sedans
# price                                                                      16400
# vat                                                               VAT deductible
# km                                                                     24,245 km
# registration                                                             03/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        103 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n130 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                    [\nJB 329 A X\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                             [\nLicht Grau\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BKN\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,490 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.7 l/100 km (comb)], [7.3 l/100 km (city)],...
# CO2 Emission                                           [\n130 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                           [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Fahrzeug steht in 14913 Jüterbog, Dennewi...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            8478   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                                    1.4 Automatik drive/SHZ/PDC
# body_type                                                                Compact
# price                                                                      10990
# vat                                                               VAT deductible
# km                                                                     39,000 km
# registration                                                             02/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n02/2021\n, \n139 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                       [\nKN 1665\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                             [\nKarbongrau\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BCB\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[6 l/100 km (comb)], [8 l/100 km (city)], [4....
# CO2 Emission                                           [\n139 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n             [Bluetooth, On-board computer, Radio, USB]
# \nExtras\n                                          [Alloy wheels, Touch screen]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Innenausstattung:, Stoff, Schwarz, Durchl...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1144   \
# url                            https://www.autoscout24.com//offers/audi-a1-sb...
# make_model                                                               Audi A1
# short_description                                            SB 1.6 tdi s-tronic
# body_type                                                                 Sedans
# price                                                                      19200
# vat                                                               VAT deductible
# km                                                                     13,186 km
# registration                                                             05/2018
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n24 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                           [\n936\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                        [\nbianco ghiaccio\n]
# Upholstery                                                    [\nCloth, Other\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[4 l/100 km (comb)], [4.6 l/100 km (city)], [...
# CO2 Emission                                           [\n105 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n                      [Air conditioning, Power windows]
# \nEntertainment & Media\n                                                [Radio]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [Central door lock, Driver-side airbag, Power ...
# description                    [\nALTRI OPTIONALS:,  , Appoggiabraccia centra...
# Emission Label                                              [\n1 (No sticker)\n]
# Gears                                                                    [\n7\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            6422   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description              1.6 CDTI Innovation 110cv Seamp S MT6 5 PORTE ...
# body_type                                                                 Sedans
# price                                                                      10950
# vat                                                               VAT deductible
# km                                                                    100,311 km
# registration                                                             04/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                       [\n2703695\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                 [\nGrigio\n]
# Upholstery                                                            [\nGrey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                                 NaN
# Nr. of Seats                                                                 NaN
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                                 NaN
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                                 NaN
# Emission Class                                                      [[], [], []]
# \nComfort & Convenience\n                                                    NaN
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n                                                        NaN
# description                    [\nDEK:[2703695], Per maggiori informazioni, a...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            14465  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                                    GRANDTOUR Intens dCi 90 EDC
# body_type                                                          Station wagon
# price                                                                      19490
# vat                                                               VAT deductible
# km                                                                          - km
# registration                                                             05/2019
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                           [, Pre-registered, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n48 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                       [\n1-20313\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                            [\nBlack-Pearl\n]
# Upholstery                                                                   NaN
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,461 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,267 kg\n]
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                                                                  NaN
# CO2 Emission                                                        [[], [], []]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nHallo!, Das Beratungsteam der Fa. Sonnleitn...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                    [\nAustria\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            10686  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                       1.6 CDTI Sports Tourer Aut. Edition Komb
# body_type                                                          Station wagon
# price                                                                      14970
# vat                                                               VAT deductible
# km                                                                     98,356 km
# registration                                                             09/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                           \nYes\n
# Warranty                                                                [\n, \n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# ...
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,490 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[6.1 l/100 km (comb)], [7.5 l/100 km (city)],...
# CO2 Emission                                           [\n139 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Sport seats, Touch screen, Voic...
# \nSafety & Security\n          [ABS, Adaptive headlights, Blind spot monitor,...
# description                    [\n, Sonderausstattung:, Innovations-Paket,  I...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            3082   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description              Sportback 1.6 TDI Sport Lease Edition *XENON+N...
# body_type                                                                Compact
# price                                                                      15445
# vat                                                               VAT deductible
# km                                                                    200,814 km
# registration                                                             09/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         82 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                      \n09/2019\n
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                   [\n, \n, \n104 g CO2/km (comb)\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                        [\nKJ204V\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                  [\nGrijs\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,250 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                           [\n104 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n                                     [CD player, Radio]
# \nExtras\n                         [Alloy wheels, Sport seats, Sport suspension]
# \nSafety & Security\n          [Alarm system, Central door lock, Driver-side ...
# description                    [\n*LET OP EXPORT PRIJS, PRIJS NEDERLAND € 17....
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                [\nNetherlands\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            5902   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                      1.4 Turbo Aut. Exclusiv Navi/Standh/Xenon
# body_type                                                          Station wagon
# price                                                                      14499
# vat                                                               VAT deductible
# km                                                                     72,700 km
# registration                                                             03/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        103 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n158 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                          [\n3527\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                         [\nSchneeWeiss/SummitWhite/Arctic\n]
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/ASL\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,364 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[6.7 l/100 km (comb)], [8.5 l/100 km (city)],...
# CO2 Emission                                           [\n158 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Digital radio, Hands-fr...
# \nExtras\n                                             [Alloy wheels, Roof rack]
# \nSafety & Security\n          [ABS, Adaptive headlights, Blind spot monitor,...
# description                    [\n, Innenausstattung:, Teilleder, Schwarz, Be...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            11194
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description              SPORTS TOURER Cosmo Pack Cdti 136 Start/stop +...
# body_type                                                          Station wagon
# price                                                                      15000
# vat                                                                         None
# km                                                                     73,130 km
# registration                                                             08/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2016, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                                   NaN
# Body Color Original                                             [\nGris Clair\n]
# Upholstery                                                                   NaN
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                                 NaN
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.8 l/100 km (city)],...
# CO2 Emission                                           [\n109 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n                                                    NaN
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n                                                        NaN
# description                    [\nCette voiture sera facturée 12 500 euros HT...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %%
df.make_model.unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %% [markdown]
# - It looks like there is nothing wrong with make_model column but It is very early to talk about it.

# %%
df.short_description.describe()
# Out:
# count                                 15873
# unique                                10001
# top       SPB 1.6 TDI 116 CV S tronic Sport
# freq                                     64
# Name: short_description, dtype: object

# %%
df.vat.describe()
# Out:
# count              11406
# unique                 2
# top       VAT deductible
# freq               10980
# Name: vat, dtype: object

# %%
df.vat.unique()
# Out:
# array(['VAT deductible', 'Price negotiable', None], dtype=object)

# %%
df.prev_owner.unique()
# Out:
# array(['2 previous owners', None, '1 previous owner', '3 previous owners',
#        '4 previous owners'], dtype=object)

# %%
df.description.describe()
# Out:
# count     15919
# unique    12874
# top          []
# freq        636
# Name: description, dtype: object

# %%
df.Type.describe()
# Out:
# count                                       15917
# unique                                        169
# top       [, Used, , Diesel (Particulate Filter)]
# freq                                         3475
# Name: Type, dtype: object

# %%
df['Previous Owners'].describe()
# Out:
# count      9279
# unique      102
# top       \n1\n
# freq       8101
# Name: Previous Owners, dtype: object

# %%
df['Next Inspection'].describe()
# Out:
# count            3535
# unique           1399
# top       \n04/2022\n
# freq               62
# Name: Next Inspection, dtype: object

# %%
df['Inspection new'].unique
# Out:
# <bound method Series.unique of 0                     [\nYes\n, \nEuro 6\n]
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4        [\nYes\n, \n109 g CO2/km (comb)\n]
#                         ...
# 15914                                   NaN
# 15915                                   NaN
# 15916           [\nYes\n, \nEuro 6d-TEMP\n]
# 15917                                   NaN
# 15918    [\nYes\n, \n153 g CO2/km (comb)\n]
# Name: Inspection new, Length: 15919, dtype: object>

# %%
df.Warranty.describe()
# Out:
# count                    10499
# unique                     515
# top       [\n, \n, \nEuro 6\n]
# freq                      1868
# Name: Warranty, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# - Here that we have got some random rows. I have to admit that I did not fall in love at first sight since it is such a messy data. :)
# - As you can see, there are so mays things that we need to do !
# - Just to make sure that we do not miss anything, I am going to make a list about things that I need to work on.

# %% [markdown]
# <br>

# %% [markdown]
# 1. Change registiration column name as registration_date and also the data type to date.
# 2. Remove the "km" from the rows and change the data type to int or float.
# 3. Remove the kW column since It doesn't have any non-null value.
# 4. Change [] in description column to "None".
# 5. Think about "previous order" column if it does make sense to change null values to "no previous owner"
# 6. Think about hp column and decide which one is better, if to use it as hp or kW
# 7. Split the type column as used or not and fuel type
# 8. There 2 different columns about previous owners, and prev_owner
# 9. Discuss the removing "\n"
