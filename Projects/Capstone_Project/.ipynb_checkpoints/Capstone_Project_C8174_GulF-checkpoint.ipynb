# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## EDA for Car Price Prediction Model

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# - - -

# %% [markdown]
# <img src="readme.png" style="height:1000px">

# %%
df = pd.read_json("scout_car.json", lines=True)

# %%
df.sample(10)
# Out:
#                                                      url      make_model  \
# 15481  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 6446   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 2053   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 6956   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 7687   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 6140   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 10066  https://www.autoscout24.com//offers/opel-corsa...      Opel Corsa
# 8817   https://www.autoscout24.com//offers/opel-corsa...      Opel Corsa
# 3777   https://www.autoscout24.com//offers/audi-a3-1-...         Audi A3
# 5505   https://www.autoscout24.com//offers/audi-a3-sp...         Audi A3
#
#                                        short_description body_type  price  \
# 15481              1.6 dci energy Intens 160cv 7p.ti edc       Van  32750
# 6446   5tg Business 1.6CDTI EU6 Schiebedach Navi Klim...    Sedans  10980
# 2053     Sportback 30 TFSI LED virtual PDC+ SHZ advanced    Sedans  26850
# 6956            Edition 1.6 CDTI ecoFlex EURO6 Klima PDC    Sedans  11590
# 7687   K 5türig 120 Jahre 1.4 Turbo s/s EU6d-T LED Na...    Sedans  26990
# 6140                  Edition 1.6 CDTI EURO6 IntelliLink    Sedans  10740
# 10066         E 1.4 120J 5-T. AT6 IntelliLink Kamera Shz   Compact  15650
# 8817               1.4 Edition KLIMA PDC SHZ INTELLILINK   Compact  13690
# 3777                   1.6 TDi Business Edition S tronic    Sedans  21900
# 5505              Sportback 30 TDI Business,Navi,6d TEMP    Sedans  23900
#
#                   vat         km registration        prev_owner  kW  ...  \
# 15481            None       - km      02/2018              None NaN  ...
# 6446   VAT deductible  67,160 km      06/2016  1 previous owner NaN  ...
# 2053   VAT deductible   3,000 km      03/2019  1 previous owner NaN  ...
# 6956   VAT deductible  54,846 km      02/2017  1 previous owner NaN  ...
# 7687   VAT deductible      12 km          -/-              None NaN  ...
# 6140   VAT deductible  71,929 km      01/2017  1 previous owner NaN  ...
# 10066  VAT deductible      10 km      04/2019  1 previous owner NaN  ...
# 8817   VAT deductible   9,900 km      11/2018              None NaN  ...
# 3777   VAT deductible  24,709 km      09/2017  1 previous owner NaN  ...
# 5505   VAT deductible       - km          -/-  1 previous owner NaN  ...
#
#                                              description   Emission Label  \
# 15481  [\n- Euro 6, - 4 Prese USB due sulla 1 deg fil...              NaN
# 6446   [\n, Getriebe:,  Schaltgetriebe, Technik:,  Bo...              NaN
# 2053   [\n, Modell,  , Advanced, Interieur,  , Alumin...              NaN
# 6956   [\nKlimaanlage, Multimedia-Schnittstelle (USB ...              NaN
# 7687   [\n, Getriebe:,  Automatik, Technik:,  Bordcom...              NaN
# 6140   [\nKlimaanlage, Multimedia-Schnittstelle (USB ...              NaN
# 10066  [\nAngebots-Nr. K4275050, Ausstattung:,  , Nav...  [\n4 (Green)\n]
# 8817   [\nFahrzeug-Nr.: 4035256-349OR (349OR)., Media...  [\n4 (Green)\n]
# 3777   [\n, Bij Arval koopt u in alle vertrouwen:, Sl...              NaN
# 5505   [\n, EU-Neuwagen mit Tageszulassung 30.11.2018...  [\n4 (Green)\n]
#
#          Gears Country version Electricity consumption  \
# 15481      NaN             NaN                     NaN
# 6446   [\n6\n]   [\nGermany\n]                     NaN
# 2053   [\n7\n]             NaN                     NaN
# 6956       NaN             NaN                     NaN
# 7687   [\n6\n]   [\nGermany\n]                     NaN
# 6140       NaN             NaN                     NaN
# 10066      NaN             NaN                     NaN
# 8817       NaN             NaN                     NaN
# 3777   [\n7\n]   [\nBelgium\n]                     NaN
# 5505   [\n6\n]   [\nGermany\n]                     NaN
#
#                             Last Service Date Other Fuel Types Availability  \
# 15481                                     NaN              NaN          NaN
# 6446                                      NaN              NaN          NaN
# 2053                                      NaN              NaN          NaN
# 6956                                      NaN              NaN          NaN
# 7687                                      NaN     [[], [], []]          NaN
# 6140                                      NaN              NaN          NaN
# 10066                                     NaN              NaN          NaN
# 8817                                      NaN              NaN          NaN
# 3777   [\n10/2017\n, \n102 g CO2/km (comb)\n]              NaN          NaN
# 5505                                      NaN              NaN          NaN
#
#       Last Timing Belt Service Date Available from
# 15481                           NaN            NaN
# 6446                            NaN            NaN
# 2053                            NaN   \n29/06/19\n
# 6956                            NaN            NaN
# 7687                            NaN            NaN
# 6140                            NaN            NaN
# 10066                           NaN            NaN
# 8817                            NaN            NaN
# 3777                            NaN            NaN
# 5505                            NaN            NaN
#
# [10 rows x 54 columns]
