# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## EDA for Car Price Prediction Model

# %% [markdown]
# In this project we are going to be cleaning and analyzing a file which has some information aboout the cars.

# %% [markdown]
# - Before start analyzing first let's import the libraries we might use for further steps.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# - - -

# %% [markdown]
# <img src="readme.png" style="height:1000px">

# %% [markdown]
# - Right after importing the libraries, I am going to read the json file that I am going to be working on.

# %%
df = pd.read_json("scout_car.json", lines=True)

# %% [markdown]
# - To get an idea of what the data looks like, let's have a look at that by getting some random samples.

# %%
df.sample(10)
# Out:
#                                                      url      make_model  \
# 12972  https://www.autoscout24.com//offers/opel-insig...   Opel Insignia
# 14072  https://www.autoscout24.com//offers/renault-cl...    Renault Clio
# 5776   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 15035  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 12517  https://www.autoscout24.com//offers/opel-insig...   Opel Insignia
# 12484  https://www.autoscout24.com//offers/opel-insig...   Opel Insignia
# 7959   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 11618  https://www.autoscout24.com//offers/opel-insig...   Opel Insignia
# 4324   https://www.autoscout24.com//offers/audi-a3-1-...         Audi A3
# 2121   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
#
#                                   short_description      body_type  price  \
# 12972           ST 1.6CDTI S&S Selective ecoTEC 110  Station wagon  21992
# 14072   IV ESTATE Clio Estate Zen Dci 90 Energy Edc  Station wagon  16620
# 5776                     K Sports Tourer INNOVATION  Station wagon  15900
# 15035                 dCi 160 Zen Energy TT EDC 118    Transporter  24900
# 12517               ST Innovation+Navi+SHZ+PDC+DAB+  Station wagon  36491
# 12484                           Grand Sport Dynamic         Sedans  33990
# 7959   5trg 1.0 Selection Radio 4.0 IntelliLink, Kl         Sedans  16990
# 11618                             Sports Tourer 1.5          Other  17170
# 4324                                        1.6 TDI        Compact  17490
# 2121       Sportback 30 TFSI S Tronic 85 kW (116 CV         Sedans  25500
#
#                   vat         km registration         prev_owner  kW  ...  \
# 12972            None       - km          -/-               None NaN  ...
# 14072            None     784 km          -/-               None NaN  ...
# 5776             None  45,581 km      05/2016  2 previous owners NaN  ...
# 15035            None  16,955 km      05/2016               None NaN  ...
# 12517  VAT deductible     301 km      04/2019   1 previous owner NaN  ...
# 12484  VAT deductible      10 km      05/2019   1 previous owner NaN  ...
# 7959   VAT deductible       5 km      04/2019   1 previous owner NaN  ...
# 11618            None   7,120 km      06/2017  2 previous owners NaN  ...
# 4324   VAT deductible  41,000 km      06/2017   1 previous owner NaN  ...
# 2121   VAT deductible      10 km      02/2019               None NaN  ...
#
#                                              description   Emission Label  \
# 12972                                                 []              NaN
# 14072  [\nCette voiture sera facturée 13 850 euros HT...              NaN
# 5776   [\n4 Einstiegstüren, CarGarantie, Zustand: gut...              NaN
# 15035  [\n¡Transparentes 100%!Nuestro Precio Final es...              NaN
# 12517  [\n, Highlights: ,  Herstellereigene Garantie ...              NaN
# 12484  [\nKEYLESS-GO, Automatic, Kindersitzbefestigun...              NaN
# 7959   [\n, Fahrzeugnummer: G353185, Klimaanlage, Eur...  [\n4 (Green)\n]
# 11618  [\nFlip Chip met., 6-Gang-Schaltgetriebe, ABS ...              NaN
# 4324   [\n, Description : , Audi A3 Sportback, 1.6 TD...              NaN
# 2121   [\n, Equipamiento incluido, [, 0UK, ] Salidas ...              NaN
#
#          Gears Country version    Electricity consumption Last Service Date  \
# 12972  [\n6\n]             NaN                        NaN               NaN
# 14072  [\n6\n]             NaN                        NaN               NaN
# 5776   [\n6\n]   [\nGermany\n]                        NaN               NaN
# 15035  [\n6\n]             NaN                        NaN               NaN
# 12517  [\n6\n]   [\nGermany\n]  [\n0 kWh/100 km (comb)\n]               NaN
# 12484  [\n6\n]             NaN                        NaN               NaN
# 7959   [\n5\n]   [\nGermany\n]                        NaN               NaN
# 11618      NaN             NaN                        NaN               NaN
# 4324   [\n6\n]   [\nBelgium\n]                        NaN     [\n04/2019\n]
# 2121   [\n7\n]             NaN                        NaN               NaN
#
#       Other Fuel Types Availability Last Timing Belt Service Date  \
# 12972              NaN          NaN                           NaN
# 14072              NaN          NaN                           NaN
# 5776               NaN          NaN                           NaN
# 15035              NaN          NaN                           NaN
# 12517              NaN          NaN                           NaN
# 12484              NaN          NaN                           NaN
# 7959      [[], [], []]          NaN                           NaN
# 11618              NaN          NaN                           NaN
# 4324               NaN          NaN                           NaN
# 2121               NaN          NaN                           NaN
#
#       Available from
# 12972            NaN
# 14072            NaN
# 5776             NaN
# 15035            NaN
# 12517            NaN
# 12484            NaN
# 7959             NaN
# 11618            NaN
# 4324             NaN
# 2121             NaN
#
# [10 rows x 54 columns]

# %% [markdown]
# - Here that we have got some random rows. I have to admit that I did not fall in love at first sight since it is such a messy data. :)
