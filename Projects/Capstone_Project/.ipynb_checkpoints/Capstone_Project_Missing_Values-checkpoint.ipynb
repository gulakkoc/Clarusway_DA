# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('df1_clean.csv')

# %%
df.T
# Out:
#                                                                  0      \
# Body_Type                                                       Sedans
# Price                                                            15770
# Vat                                                     VAT deductible
# Km                                                               56013
# Previous_Owner                                                     2.0
# kW                                                                66.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A1
# Registration_Year                                               2016.0
# Body_Color                                                       Black
# Paint_Type                                                    Metallic
# ...

# %%
df1 = df.copy()

# %%
df1[df1.Body_Type.isnull()]
# Out:
#       Body_Type  Price               Vat      Km  Previous_Owner     kW  \
# 3175        NaN  14400               NaN  119000             1.0   81.0
# 3255        NaN  18500  Price negotiable   70000             NaN   81.0
# 3975        NaN  19950               NaN   25000             2.0   85.0
# 3997        NaN  19750    VAT deductible   38800             1.0   82.0
# 4206        NaN  18490               NaN   20000             NaN   92.0
# 4297        NaN  17990               NaN   20000             NaN   92.0
# 4298        NaN  17990               NaN   20000             NaN   92.0
# 5718        NaN  12990               NaN   47000             NaN  100.0
# 5938        NaN  12990               NaN   47000             NaN  100.0
# 5940        NaN  12990               NaN   47000             NaN  100.0
# 6920        NaN  11990               NaN   64000             NaN   81.0
# 6922        NaN  11990               NaN   64000             NaN   81.0
# ...

# %%
df1.isnull().sum()
# Out:
# Body_Type                60
# Price                     0
# Vat                    4513
# Km                        0
# Previous_Owner         6828
# kW                       88
# Condition                 2
# Make                      0
# Model                     0
# Registration_Year      1597
# Body_Color              597
# Paint_Type             5772
# Upholstery             3720
# Nr_of_Doors             212
# Nr_of_Seats             977
# Gearing_Type              0
# Displacement            496
# Cylinders              5680
# Drive_Chain            6858
# Fuel                      0
# CO2_Emission           2436
# Emission_Class         3628
# Comfort_Convenience     920
# Entertainment_Media    1374
# Extras                 2962
# Safety_Security         982
# Gears                  4712
# Combined_Cons          2883
# dtype: int64

# %%
df1[df1.Body_Type == None & df1.Fuel == "Gasoline"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-5bd3ba7c06f3> in <module>
# ----> 1 df1[df1.Body_Type == None & df1.Fuel == "Gasoline"]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
